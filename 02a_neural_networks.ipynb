# %% [markdown]
# # Music machine learning - Neural networks
#
# ### Author: Philippe Esling (esling@ircam.fr)
#
# In this course we will cover
# 1. A [quick introduction](#intro) on the code that we will adress and auxiliary functions
# 2. A simple implementation for a [single neuron](#single)
# 3. An implementation of [regression](#implem) using scikit-learn
# 4. Some [common good practices](#practices) in machine learning

# %% [markdown]
# # Introducing neural networks

# %% [markdown]
# In this tutorial, we will cover a more advanced classification algorithm through the use of *neural networks*. The tutorial starts by performing a simple **single neuron** discrimination of two random distributions. Then, we will study the typical **XOR problem** by using a more advanced 2-layer **perceptron**. Finally, we generalize the use of neural networks in order to perform classification on a given set of audio files.

# %% [markdown]
# We are going to use relatively _low-level_ libraries to perform the first exercises (implementing your own neurons)

# %%
import time
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# To simplify your work, we provide a first set of functions that provides simple plotting functionnalities (from the `helper_plot.py` file)
#
#   |**File**|*Explanation*|
#   |-------:|:---------|
#   |`plot_boundary`|Plots the decision boundary of a single neuron with 2-dimensional inputs|
#   |`plot_patterns`|Plots (bi-dimensionnal) input patterns|

# %%
from helper_plot import plot_boundary    #plot la droite de séparation (l'hyperplan en dim 2)
from helper_plot import plot_patterns

# %% [markdown]
# Remember that a single neuron is only able to learn _linearly separable_ problems. To produce such classes of problems, we provide a script that draw a set of random 2-dimensional points, then choose a random line in this space that will act as the linear frontier between 2 classes (hence defining a linear 2-class problem). The variables that will be used by your code are the following.
#
# ```Matlab
# desired       % classes of the patterns
# inputs        % 2 x n final matrix of random input patterns
# weights       % 2 x 1 vector of neuron weights
# bias          % 1 x 1 vector of bias
# ```
#
# You can execute the code below to see our simple classification problem. (Note that running the same cell multiple times produces a different starting dataset).

# %%
# Number of points to generate
nPats = 30 + np.floor(np.random.rand() * 30);
# Generate 2-dimensional random points
patterns = np.random.rand(2, int(nPats)) * 2 - 1;
# Slope of separating line
slope = np.log(np.random.rand() * 10);
yint = np.random.rand() * 2 - 1;
#print(yint)
# Create the indexes for a two-class problem
desired = (patterns[1,:] - patterns[0,:] * slope - yint > 0) * 1;
#print(desired) #-> vert ou bleu
#print(patterns) #-> coordonnées des points
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);

# %% [markdown]
# ## Single neuron
#
# For the first parts of the tutorial, we will perform the simplest classification model possible in a neural network setting, a single neuron. We briefly recall here that; given an input vector $ \mathbf{x} \in \mathbb{R}^{n} $, a single neuron computes the function
#
# $$
# \begin{equation}
# \hat{y}=\phi\left(\sum_{i = 1}^{n}w_{i}.x_{i} + b\right)
# \label{eq1}
# \end{equation}
# $$
#
# with $ \mathbf{w} \in \mathbb{R}^{n} $ a weight vector, $ b $ a bias and $ \phi\left(\cdot\right) $ an *activation function*. Therefore, if we consider the *threshold* activation function ($ \phi_{0}\left(x\right)=1 $ if $ x \geq 0$), a single neuron simply performs an *affine transform* and then a *linear* discrimination of the space. A network will be composed of _layers_ of these neurons, which produce successive computations
#
# <img src="images/02_feedforward_nn.png" align="center"/>
#
# Geometrically, a single neuron computes an hyperplane that separates the space. In order to learn, we have to adjust the weights and know "how much wrong we are". To do so, we consider that we know the desired output $ d $ of a system for a given example $ \mathbf{x} $ (eg. a predicted value for a regression system, a class value for a classification system). Therefore, we define the loss function $ \mathcal{L}_{\mathcal{D}} $ over a whole dataset as
#
# $$
# \begin{equation}
# \mathcal{L}_{\mathcal{D}}=\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\hat{y}_{j}\right\Vert ^{2}
# \label{eq2}
# \end{equation}
# $$
#
# In order to know how to change the weights based on the value of the errors, we need to now "how to change it to make it better". Therefore, we should compute the sets of derivatives of the error given each parameter
#
# $$
# \begin{equation}
# \Delta\bar{\mathbf{w}}=\left(\frac{\delta\mathcal{L}}{\delta w_{1}},\ldots,\frac{\delta\mathcal{L}}{\delta w_{n}}\right)
# \label{eq3}
# \end{equation}
# $$
#
# ***
#
# **Exercise**
#
#   1. Perform the derivatives of the output given a single neuron
#   2. Perform the derivatives for the bias as well
#
# ***

# %% [markdown]
# 1. Perform the derivations of the error (???) given a single neuron
#
# En indicant $j$ les différentes entrées, et $i$ les poids :
#
# $$
# \begin{align}
#     \frac{\delta}{\delta w_i}[L_D] &= \sum_j \frac{\delta}{\delta w_i}(y_j - \hat{y}_j)^2 \\
#     &= \sum_j -2(y_j - \hat{y}_j)\frac{\delta \hat{y}_j}{\delta w_i} \\
# \end{align}
# $$
#
# avec, en notant $x_{j,k}$ la k-ème coordonnées de l'entrée $x_j$:
#
# $$
# \begin{align}
#     \frac{\delta \hat{y}_j}{\delta w_i} &= \frac{\delta}{\delta w_i} \phi (\sum_k x_{j,k} w_k + b) \\
#     &= \phi'(\sum_k x_{j,k} w_j + b) \frac{\delta}{\delta w_i}(\sum_k x_{j,k} w_k + b) \\
# \end{align}
# $$
#
# la dernière dérivée étant égale à $x_{j,i}$.
#
# Finalement :
#
# $$\frac{\delta}{\delta w_i}[L_D] = \sum_j -2(y_j - \hat{y}_j)\phi'(\sum_k x_{j,k} w_j + b)x_{j,i} $$
#
#
#   2. Perform the derivatives for the bias as well
#
#  Le calcul est identique sauf que la dernière dérivée vaut 1 :
#
#  $$\frac{\delta}{\delta b}[L_D] = \sum_j -2(y_j - \hat{y}_j)\phi'(\sum_k x_{j,k} w_j + b)$$
#
#
#  La formule de mise à jour des poids et du biais, pour minimiser l'erreur, est :
#
#  $$ \theta_{t+1} = \theta_{t} - \eta \big[grad_{\theta} L_{D}\big]_{\theta_t} $$
#
# (le vecteur gradient pointe vers les valeurs croissantes d'où le - dans la formule).
#
#
# Pour la suite j'utilise comme fonction d'activation $\phi$ la sigmoïd (je ne comprends pas bien dans l'énoncé si il faut utiliser la fonction seuil ? cela me parait étrange car alors le gradient serait tjrs nul...). J'ai alors :
#
# $$ \phi'(\hat{y}) = \hat{y}(1 - \hat{y}) $$

# %% [markdown]
# ### Training your own neuron
#
# We will start by training a single neuron to learn how to perform this discrimination with a linear problem (so that a single neuron is enough to solve it).

# %%
# Inputs to use
inputs = patterns;
# Initialize the weights
weights = np.random.randn(1, 2);   #2 poids car espace 2D
bias = np.random.randn(1, 1)
# Learning rate
eta = 0.05;
# Weight decay
lambdaW = 0.1

# %% [markdown]
# Now you need to update the following code loop to ensure that your neuron learns to separate between the classes
# ***
#
# **Exercise**
#   1. Update the loop so that it computes the forward propagation error
#   2. Update the loop to perform learning (based on back-propagation)
#   3. Run the learning procedure, which should produce a result similar to that displayed on the website
#   4. Perform multiple re-runs by **tweaking the hyperparameters** (learning rate, weight decay)
#   5. What observations can you make on the learning process?
#   6. (Optional) Change the input patterns, and confirm your observations.
#   6. (Optional) Incorporate the bias in the weights to obtain a **vectorized** code.
#
# ***

# %%
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);
plt.draw()

def sig(x):   #définition de la fonction sigmoid
    return 1/(1+np.exp(-x))

# Update loop
for i in range(50):   #50 = nb d'itérations dans la descente de gradient
    
    y_hat = sig(np.dot(weights, inputs) + bias) #calcul des y_hat pour toutes les entrées
    
    # y_hat = (weights * inputs + bias) > 0
    
    L = np.sum((desired - y_hat)**2)   #calcul de l'erreur pour tous les y_hat
    
    var =-2*(desired - y_hat)*y_hat*(1-y_hat)   #constante qui revient dans les calculs de gradient
    
    #calcul des gradients par rapport au biais et aux poids
    grad_b = np.sum(var)
    
    grad_w = np.sum(var*inputs, axis=1)
    
    bias -= eta*grad_b   #mise à jour des biais et des poids
    weights -= eta*grad_w
    
    #on peut mettre un break pour s'arrêter lorsque l'erreur est nulle
    
    print('%2d.  weights = %f, %f, %f    loss = %f' % (i, bias[0, 0], weights[0, 0], weights[0, 1], L))
    plot_boundary(np.concatenate((bias, weights), axis=1), i, '--', fig)
    plt.draw()
    time.sleep(0.2)
plot_boundary(np.concatenate((bias, weights), axis=1), i, '-', fig);
# Out:
#  0.  weights = -1.887359, 0.444003, -0.579439    loss = 18.910934
#  1.  weights = -1.656647, 0.552922, -0.544053    loss = 17.835127
#  2.  weights = -1.394533, 0.678328, -0.498763    loss = 16.412071
#  3.  weights = -1.105521, 0.817280, -0.441439    loss = 14.582224
#  4.  weights = -0.805754, 0.960140, -0.371853    loss = 12.401371
#  5.  weights = -0.521667, 1.092504, -0.293151    loss = 10.136635
#  6.  weights = -0.276023, 1.204514, -0.210498    loss = 8.169589
#  7.  weights = -0.076182, 1.296152, -0.128077    loss = 6.706880
#  8.  weights = 0.082213, 1.372464, -0.048142    loss = 5.702771
#  9.  weights = 0.207166, 1.438401, 0.028361    loss = 5.020647
# 10.  weights = 0.306255, 1.497368, 0.101166    loss = 4.544451
# 11.  weights = 0.385588, 1.551460, 0.170328    loss = 4.197874
# 12.  weights = 0.449829, 1.601940, 0.236039    loss = 3.934292
# 13.  weights = 0.502481, 1.649577, 0.298532    loss = 3.725540
# 14.  weights = 0.546171, 1.694861, 0.358045    loss = 3.554382
# 15.  weights = 0.582873, 1.738121, 0.414803    loss = 3.410020
# 16.  weights = 0.614086, 1.779592, 0.469012    loss = 3.285495
# 17.  weights = 0.640950, 1.819449, 0.520858    loss = 3.176179
# 18.  weights = 0.664345, 1.857837, 0.570509    loss = 3.078891
# 19.  weights = 0.684949, 1.894873, 0.618117    loss = 2.991371
# 20.  weights = 0.703295, 1.930661, 0.663820    loss = 2.911964
# 21.  weights = 0.719798, 1.965292, 0.707741    loss = 2.839420
# 22.  weights = 0.734788, 1.998848, 0.749995    loss = 2.772769
# 23.  weights = 0.748527, 2.031402, 0.790685    loss = 2.711241
# 24.  weights = 0.761223, 2.063022, 0.829905    loss = 2.654209
# 25.  weights = 0.773045, 2.093769, 0.867744    loss = 2.601158
# 26.  weights = 0.784130, 2.123701, 0.904280    loss = 2.551655
# 27.  weights = 0.794587, 2.152868, 0.939589    loss = 2.505333
# 28.  weights = 0.804506, 2.181319, 0.973739    loss = 2.461875
# 29.  weights = 0.813962, 2.209098, 1.006792    loss = 2.421010
# 30.  weights = 0.823015, 2.236244, 1.038807    loss = 2.382498
# 31.  weights = 0.831716, 2.262795, 1.069840    loss = 2.346132
# 32.  weights = 0.840107, 2.288784, 1.099940    loss = 2.311726
# 33.  weights = 0.848221, 2.314244, 1.129155    loss = 2.279118
# 34.  weights = 0.856090, 2.339203, 1.157530    loss = 2.248161
# 35.  weights = 0.863737, 2.363689, 1.185104    loss = 2.218725
# 36.  weights = 0.871183, 2.387725, 1.211918    loss = 2.190695
# 37.  weights = 0.878446, 2.411336, 1.238007    loss = 2.163963
# 38.  weights = 0.885542, 2.434541, 1.263404    loss = 2.138436
# 39.  weights = 0.892483, 2.457362, 1.288142    loss = 2.114027
# 40.  weights = 0.899280, 2.479815, 1.312250    loss = 2.090660
# 41.  weights = 0.905944, 2.501919, 1.335757    loss = 2.068262
# 42.  weights = 0.912483, 2.523688, 1.358688    loss = 2.046770
# 43.  weights = 0.918904, 2.545138, 1.381069    loss = 2.026124
# 44.  weights = 0.925214, 2.566282, 1.402923    loss = 2.006270
# 45.  weights = 0.931419, 2.587134, 1.424272    loss = 1.987160
# 46.  weights = 0.937524, 2.607704, 1.445138    loss = 1.968747
# 47.  weights = 0.943533, 2.628004, 1.465539    loss = 1.950991
# 48.  weights = 0.949451, 2.648045, 1.485494    loss = 1.933852
# 49.  weights = 0.955282, 2.667837, 1.505022    loss = 1.917295

# %%
y_hat.shape
# Out:
# (1, 34)

# %% [markdown]
# Le résultat obtenu est satisfaisant, les deux domaines sont bien séparés.
#
# Si on augmente $\eta$, on augmente la "vitesse" à laquelle les poids et le biais sont mis à jour, c'est-à-dire la distance de laquelle s'écarte le nouveau poids ou biais de sa position précédente dans la direction du gradient, à chaque itération. Si $\eta$ devient trop grand le minimum peut être "raté" par la descente de gradient dans le sens où les poids "rebondissent" de part et d'autre du minimum sans jamais l'atteindre. (C'est peu le cas ici du fait de mon choix de fonction d'activation sigmoïd dont la dérivée devient très proche de 0 en-dessous de -0.5 et au-dessus de +0.5).

# %% [markdown]
# ### 2-layer XOR problem
#
# In most cases, classification problems are far from being linear. Therefore, we need more advanced methods to be able to compute non-linear class boundaries. The advantage of neural networks is that the same principle can be applied in a *layer-wise* fashion. This allows to further discriminate the space in sub-regions (as seen in the course). We will try to implement the 2-layer *perceptron* that can provide a solution to the infamous XOR problem. The idea is now to have the output of the first neurons to be connected to a set of other neurons. Therefore, if we take back our previous formulation, we have the same output for the first neuron(s) $\hat{y}$, that we will now term as $y^{(1)}$. Then, we feed these outputs to a second layer of neurons, which gives
#
#
# $$
# \begin{equation}
# y^{(2)}=\phi\left(\sum_{i = 1}^{n}w_{i}.y^{(1)}_{i} + b\right)
# \label{eq6}
# \end{equation}
# $$
#
# Finally, we will rely on the same loss $\mathcal{L_{D}}$ as in the previous exercise, but the outputs used are $y_2$ instead of $y$. As in the previous case, we now need to compute the derivatives of the weights and biases for several layers . However, you should see that some form of generalization might be possible for any number of layer.

# %% [markdown]
# ***
#
# **Exercise**
#   1. Perform the derivatives for the last layer specifically
#   2. Define a generalized derivative for any previous layer
#
# ***
#
# 1. Perform the derivatives for the last layer specifically
#
# Pour la dernière couche, on se retrouve dans la même situation que précédemment avec simplement les entrées du neurone qui sont les sorties des neurones de la couche précédente.
#
# On retrouve les mêmes formules que précédemment en remplaçant le vecteur $x$ par $y^{(1)}$ et le vecteur $\hat{y}$ par $y^{(2)}$.
#
# 2. Define a generalized derivative for any previous layer
#
# On déduit la couche précédente par les formules suivantes :
#
# $$\frac{\delta L}{\delta w^{(1)}} = \frac{\delta L}{\delta w^{(2)}}(1-y^{(1)}w^{(2)}x$$
# et
# $$\frac{\delta L}{\delta b^{(1)}} = \frac{\delta L}{\delta b^{(2)}}y^{(1)}(1-y^{(1)}w^{(2)}$$

# %% [markdown]
# We can construct the prototypical set of XOR values by using the following code (note that this is the most simple case, but still this is typically a problem that cannot be solved by a _linear classifier_

# %%
patterns = np.array([[-1, -1],[-1,  1],[1, -1],[1,  1]]).transpose() # Input patterns
desired = np.array([0, 1, 1, 0])  # Corresponding classes
out_patterns = []
out_desired = []  
n_augment = 100
for p in range(4):
    rep_pat = np.repeat(patterns[:, p][:, np.newaxis], n_augment, axis=1)
    out_patterns.append(np.random.randn(2, n_augment) * 0.1 + rep_pat)
    out_desired.append(np.repeat([desired[p]], n_augment))
out_patterns = (np.concatenate(out_patterns, axis=1))
out_desired = (np.concatenate(out_desired))
# Initialize based on their sizes
nInputs = out_patterns.shape[0]
nOutputs = 1
nPat = out_patterns.shape[1]
# First plot the patterns
fig = plot_patterns(out_patterns, out_desired);

# %% [markdown]
# The variables that will be used by your code are the following.
#
# ```Matlab
# patterns          % 2 x n matrix of random points
# desired           % classes of the patterns
# inputs1           % 3 x n final matrix of inputs (accounting for bias)
# nHiddens          % Number of hidden units
# learnRate         % Learning rate parameter
# momentum          % Momentum parameter (bonus)
# weights1          % 1st layer weights
# weights2          % 2nd layer weights
# TSS_Limit         % Sum-squared error limit
# ```

# %%
nHiddens = 2     #taille de y1      # Number of hidden units
learnRate = 0.001       # Learning rate parameter
momentum = 0.1         # Momentum parameter
# Overall input patterns
inputs = out_patterns
TSS_Limit = 0.02                                           # Sum-squared error limit
# Learning rate
eta = 0.001

# %% [markdown]
# ***
#
# **Exercise**
#
#   1. Update the forward propagation and error computation (compared to desired).
#   2. Update the back-propagation part to learn the weights of both layers.
#   3. Run the learning, which should produce a result similar to that displayed below.
#   4. Perform multiple re-runs of the learning procedure (re-launching with different initializations)
#   5. What observations can you make on the learning process?
#   6. What happens if you initialize all weights to zeros?
#   7. (Optional) Implement the *sparsity* constraint in your neural network.
#   7. (Optional) Implement the *weight decay* constraint in your network.
#   7. (Optional) Add the *momentum* to the learning procedure.
#
# *For optional questions, please look after the first code box for more information*
#
# ***

# %%
inputs.shape
# Out:
# (2, 400)

# %%
# Weights of first and second layer
weights1 = (np.random.randn(nHiddens, nInputs) - 0.5)      # 1st layer weights ->(2x2) = 2 neurones
weights2 = (np.random.randn(nOutputs, nHiddens) - 0.5)     # 2nd layer weights -> (2x1) = 1 neurone
bias1 = (np.random.randn(nHiddens, 1) - 0.5)               # 1st layer biases -> (2x1)
bias2 = (np.random.randn(nOutputs, 1) - 0.5)               # 2nd layer biases -> (1x1)
# First plot the patterns
fig = plot_patterns(patterns, desired);
# Iterate for a fixed number of iterations
for epoch in range(10000):    #200
  
    # forward propagation
    
    y_1 = sig(np.dot(weights1, inputs) + bias1)  
    y_2 = sig(np.dot(weights2, y_1) + bias2)

    L = np.sum((out_desired - y_2)**2)   #calcul de l'erreur pour tous les y_hat
    
    ## Couche finale
    var2 =(out_desired - y_2)*y_2*(1-y_2)   #constante qui revient dans les calculs de gradient
    
    #calcul des gradients par rapport au biais et aux poids
    #grad_b2 = np.sum(var)
    
    #grad_w2 = np.sum(var*inputs, axis=1)
    
    grad_w2 = np.dot(var2,y_1.T)
    grad_b2 = np.mean(var2,axis=1)[:,np.newaxis]
    
    ## Couche précédente
    
    #grad_w1 = np.dot(weights2[0],grad_w2)*np.dot((1-y_1),inputs.T)
    #grad_b1 = grad_b2*np.dot(np.dot((1-y_1), y_1.T),weights2.T)
    
    #grad_b1 = np.dot(grad_b2,y_1.T)
    #grad_w1 = np.dot(grad_b1,inputs.T)
    
    var1 = np.dot(weights2.T,var2)*y_1*(1-y_1)
    
    grad_w1 = np.dot(var1,inputs.T)
    grad_b1 = np.mean(var1,axis=1)[:,np.newaxis]
    
    
    bias2 -= eta*grad_b2   #mise à jour des biais et des poids
    weights2 -= eta*grad_w2
    
    bias1 -= eta*grad_b1
    weights1 -= eta*grad_w1
    
    TSS = L
        
    print('Epoch %3d:  Error = %f' % (epoch, TSS));
    if TSS < TSS_Limit:
        break
    if (epoch - 1 % 20)==0:
        plot_boundary(np.concatenate((bias2, weights2), axis=1), epoch, '--', fig)

plot_boundary(np.concatenate((bias1, weights1), axis=1), epoch, '-', fig)
# Out:
# Epoch   0:  Error = 159.743117
# Epoch   1:  Error = 160.041486
# Epoch   2:  Error = 160.337176
# Epoch   3:  Error = 160.630202
# Epoch   4:  Error = 160.920580
# Epoch   5:  Error = 161.208327
# Epoch   6:  Error = 161.493458
# Epoch   7:  Error = 161.775990
# Epoch   8:  Error = 162.055941
# Epoch   9:  Error = 162.333327
# Epoch  10:  Error = 162.608167
# Epoch  11:  Error = 162.880478
# Epoch  12:  Error = 163.150280
# Epoch  13:  Error = 163.417590
# Epoch  14:  Error = 163.682426
# Epoch  15:  Error = 163.944809
# Epoch  16:  Error = 164.204757
# Epoch  17:  Error = 164.462290
# Epoch  18:  Error = 164.717426
# Epoch  19:  Error = 164.970185
# Epoch  20:  Error = 165.220586
# Epoch  21:  Error = 165.468650
# Epoch  22:  Error = 165.714396
# Epoch  23:  Error = 165.957843
# Epoch  24:  Error = 166.199011
# Epoch  25:  Error = 166.437921
# Epoch  26:  Error = 166.674591
# Epoch  27:  Error = 166.909043
# Epoch  28:  Error = 167.141294
# Epoch  29:  Error = 167.371366
# Epoch  30:  Error = 167.599277
# Epoch  31:  Error = 167.825048
# Epoch  32:  Error = 168.048698
# Epoch  33:  Error = 168.270247
# Epoch  34:  Error = 168.489714
# Epoch  35:  Error = 168.707118
# Epoch  36:  Error = 168.922480
# Epoch  37:  Error = 169.135817
# Epoch  38:  Error = 169.347150
# Epoch  39:  Error = 169.556497
# Epoch  40:  Error = 169.763877
# Epoch  41:  Error = 169.969310
# Epoch  42:  Error = 170.172814
# Epoch  43:  Error = 170.374407
# Epoch  44:  Error = 170.574109
# Epoch  45:  Error = 170.771937
# Epoch  46:  Error = 170.967910
# Epoch  47:  Error = 171.162046
# Epoch  48:  Error = 171.354363
# Epoch  49:  Error = 171.544879
# Epoch  50:  Error = 171.733612
# Epoch  51:  Error = 171.920580
# Epoch  52:  Error = 172.105799
# Epoch  53:  Error = 172.289288
# Epoch  54:  Error = 172.471063
# Epoch  55:  Error = 172.651143
# Epoch  56:  Error = 172.829543
# Epoch  57:  Error = 173.006280
# Epoch  58:  Error = 173.181372
# Epoch  59:  Error = 173.354834
# Epoch  60:  Error = 173.526684
# Epoch  61:  Error = 173.696937
# Epoch  62:  Error = 173.865610
# Epoch  63:  Error = 174.032718
# Epoch  64:  Error = 174.198278
# Epoch  65:  Error = 174.362305
# Epoch  66:  Error = 174.524815
# Epoch  67:  Error = 174.685823
# Epoch  68:  Error = 174.845345
# Epoch  69:  Error = 175.003395
# Epoch  70:  Error = 175.159989
# Epoch  71:  Error = 175.315141
# Epoch  72:  Error = 175.468867
# Epoch  73:  Error = 175.621180
# Epoch  74:  Error = 175.772096
# Epoch  75:  Error = 175.921628
# Epoch  76:  Error = 176.069791
# Epoch  77:  Error = 176.216599
# Epoch  78:  Error = 176.362065
# Epoch  79:  Error = 176.506204
# Epoch  80:  Error = 176.649029
# Epoch  81:  Error = 176.790554
# Epoch  82:  Error = 176.930791
# Epoch  83:  Error = 177.069755
# Epoch  84:  Error = 177.207458
# Epoch  85:  Error = 177.343914
# Epoch  86:  Error = 177.479135
# Epoch  87:  Error = 177.613133
# Epoch  88:  Error = 177.745922
# Epoch  89:  Error = 177.877514
# Epoch  90:  Error = 178.007922
# Epoch  91:  Error = 178.137156
# Epoch  92:  Error = 178.265231
# Epoch  93:  Error = 178.392157
# Epoch  94:  Error = 178.517946
# Epoch  95:  Error = 178.642611
# Epoch  96:  Error = 178.766163
# Epoch  97:  Error = 178.888612
# Epoch  98:  Error = 179.009972
# Epoch  99:  Error = 179.130252
# Epoch 100:  Error = 179.249464
# Epoch 101:  Error = 179.367620
# Epoch 102:  Error = 179.484729
# Epoch 103:  Error = 179.600804
# Epoch 104:  Error = 179.715854
# Epoch 105:  Error = 179.829889
# Epoch 106:  Error = 179.942922
# Epoch 107:  Error = 180.054961
# Epoch 108:  Error = 180.166018
# Epoch 109:  Error = 180.276101
# Epoch 110:  Error = 180.385222
# Epoch 111:  Error = 180.493391
# Epoch 112:  Error = 180.600616
# Epoch 113:  Error = 180.706909
# Epoch 114:  Error = 180.812278
# Epoch 115:  Error = 180.916732
# Epoch 116:  Error = 181.020282
# Epoch 117:  Error = 181.122937
# Epoch 118:  Error = 181.224706
# Epoch 119:  Error = 181.325598
# Epoch 120:  Error = 181.425622
# Epoch 121:  Error = 181.524787
# Epoch 122:  Error = 181.623102
# Epoch 123:  Error = 181.720575
# Epoch 124:  Error = 181.817216
# Epoch 125:  Error = 181.913033
# Epoch 126:  Error = 182.008034
# Epoch 127:  Error = 182.102227
# Epoch 128:  Error = 182.195622
# Epoch 129:  Error = 182.288225
# Epoch 130:  Error = 182.380046
# Epoch 131:  Error = 182.471092
# Epoch 132:  Error = 182.561372
# Epoch 133:  Error = 182.650892
# Epoch 134:  Error = 182.739662
# Epoch 135:  Error = 182.827687
# Epoch 136:  Error = 182.914977
# Epoch 137:  Error = 183.001539
# Epoch 138:  Error = 183.087379
# Epoch 139:  Error = 183.172506
# Epoch 140:  Error = 183.256927
# Epoch 141:  Error = 183.340649
# Epoch 142:  Error = 183.423678
# Epoch 143:  Error = 183.506023
# Epoch 144:  Error = 183.587690
# Epoch 145:  Error = 183.668686
# Epoch 146:  Error = 183.749017
# Epoch 147:  Error = 183.828691
# Epoch 148:  Error = 183.907714
# Epoch 149:  Error = 183.986092
# Epoch 150:  Error = 184.063833
# Epoch 151:  Error = 184.140943
# Epoch 152:  Error = 184.217428
# Epoch 153:  Error = 184.293294
# Epoch 154:  Error = 184.368547
# Epoch 155:  Error = 184.443195
# Epoch 156:  Error = 184.517242
# Epoch 157:  Error = 184.590696
# Epoch 158:  Error = 184.663561
# Epoch 159:  Error = 184.735844
# Epoch 160:  Error = 184.807551
# Epoch 161:  Error = 184.878687
# Epoch 162:  Error = 184.949259
# Epoch 163:  Error = 185.019271
# Epoch 164:  Error = 185.088730
# Epoch 165:  Error = 185.157640
# Epoch 166:  Error = 185.226008
# Epoch 167:  Error = 185.293839
# Epoch 168:  Error = 185.361138
# Epoch 169:  Error = 185.427910
# Epoch 170:  Error = 185.494161
# Epoch 171:  Error = 185.559896
# Epoch 172:  Error = 185.625120
# Epoch 173:  Error = 185.689838
# Epoch 174:  Error = 185.754055
# Epoch 175:  Error = 185.817776
# Epoch 176:  Error = 185.881006
# Epoch 177:  Error = 185.943750
# Epoch 178:  Error = 186.006012
# Epoch 179:  Error = 186.067797
# Epoch 180:  Error = 186.129111
# Epoch 181:  Error = 186.189957
# Epoch 182:  Error = 186.250340
# Epoch 183:  Error = 186.310264
# Epoch 184:  Error = 186.369735
# Epoch 185:  Error = 186.428757
# Epoch 186:  Error = 186.487333
# Epoch 187:  Error = 186.545469
# Epoch 188:  Error = 186.603169
# Epoch 189:  Error = 186.660436
# Epoch 190:  Error = 186.717275
# Epoch 191:  Error = 186.773691
# Epoch 192:  Error = 186.829686
# Epoch 193:  Error = 186.885267
# Epoch 194:  Error = 186.940435
# Epoch 195:  Error = 186.995196
# Epoch 196:  Error = 187.049553
# Epoch 197:  Error = 187.103510
# Epoch 198:  Error = 187.157071
# Epoch 199:  Error = 187.210240
# Epoch 200:  Error = 187.263021
# Epoch 201:  Error = 187.315416
# Epoch 202:  Error = 187.367431
# Epoch 203:  Error = 187.419068
# Epoch 204:  Error = 187.470331
# Epoch 205:  Error = 187.521224
# Epoch 206:  Error = 187.571750
# Epoch 207:  Error = 187.621913
# Epoch 208:  Error = 187.671716
# Epoch 209:  Error = 187.721163
# Epoch 210:  Error = 187.770256
# Epoch 211:  Error = 187.819000
# Epoch 212:  Error = 187.867397
# Epoch 213:  Error = 187.915451
# Epoch 214:  Error = 187.963165
# Epoch 215:  Error = 188.010542
# Epoch 216:  Error = 188.057585
# Epoch 217:  Error = 188.104298
# Epoch 218:  Error = 188.150684
# Epoch 219:  Error = 188.196745
# Epoch 220:  Error = 188.242484
# Epoch 221:  Error = 188.287905
# Epoch 222:  Error = 188.333011
# Epoch 223:  Error = 188.377804
# Epoch 224:  Error = 188.422287
# Epoch 225:  Error = 188.466464
# Epoch 226:  Error = 188.510337
# Epoch 227:  Error = 188.553908
# Epoch 228:  Error = 188.597181
# Epoch 229:  Error = 188.640158
# Epoch 230:  Error = 188.682843
# Epoch 231:  Error = 188.725237
# Epoch 232:  Error = 188.767343
# Epoch 233:  Error = 188.809165
# Epoch 234:  Error = 188.850703
# Epoch 235:  Error = 188.891962
# Epoch 236:  Error = 188.932944
# Epoch 237:  Error = 188.973651
# Epoch 238:  Error = 189.014085
# Epoch 239:  Error = 189.054250
# Epoch 240:  Error = 189.094147
# Epoch 241:  Error = 189.133779
# Epoch 242:  Error = 189.173148
# Epoch 243:  Error = 189.212258
# Epoch 244:  Error = 189.251109
# Epoch 245:  Error = 189.289704
# Epoch 246:  Error = 189.328046
# Epoch 247:  Error = 189.366136
# Epoch 248:  Error = 189.403978
# Epoch 249:  Error = 189.441573
# Epoch 250:  Error = 189.478924
# Epoch 251:  Error = 189.516032
# Epoch 252:  Error = 189.552900
# Epoch 253:  Error = 189.589530
# Epoch 254:  Error = 189.625923
# Epoch 255:  Error = 189.662083
# Epoch 256:  Error = 189.698011
# Epoch 257:  Error = 189.733709
# Epoch 258:  Error = 189.769179
# Epoch 259:  Error = 189.804423
# Epoch 260:  Error = 189.839443
# Epoch 261:  Error = 189.874241
# Epoch 262:  Error = 189.908819
# Epoch 263:  Error = 189.943179
# Epoch 264:  Error = 189.977323
# Epoch 265:  Error = 190.011252
# Epoch 266:  Error = 190.044969
# Epoch 267:  Error = 190.078475
# Epoch 268:  Error = 190.111772
# Epoch 269:  Error = 190.144862
# Epoch 270:  Error = 190.177747
# Epoch 271:  Error = 190.210428
# Epoch 272:  Error = 190.242907
# Epoch 273:  Error = 190.275186
# Epoch 274:  Error = 190.307266
# Epoch 275:  Error = 190.339150
# Epoch 276:  Error = 190.370838
# Epoch 277:  Error = 190.402333
# Epoch 278:  Error = 190.433636
# Epoch 279:  Error = 190.464749
# Epoch 280:  Error = 190.495674
# Epoch 281:  Error = 190.526411
# Epoch 282:  Error = 190.556963
# Epoch 283:  Error = 190.587330
# Epoch 284:  Error = 190.617516
# Epoch 285:  Error = 190.647520
# Epoch 286:  Error = 190.677345
# Epoch 287:  Error = 190.706993
# Epoch 288:  Error = 190.736463
# Epoch 289:  Error = 190.765759
# Epoch 290:  Error = 190.794881
# Epoch 291:  Error = 190.823831
# Epoch 292:  Error = 190.852611
# Epoch 293:  Error = 190.881221
# Epoch 294:  Error = 190.909663
# Epoch 295:  Error = 190.937939
# Epoch 296:  Error = 190.966049
# Epoch 297:  Error = 190.993996
# Epoch 298:  Error = 191.021780
# Epoch 299:  Error = 191.049403
# Epoch 300:  Error = 191.076866
# Epoch 301:  Error = 191.104171
# Epoch 302:  Error = 191.131318
# Epoch 303:  Error = 191.158309
# Epoch 304:  Error = 191.185145
# Epoch 305:  Error = 191.211828
# Epoch 306:  Error = 191.238358
# Epoch 307:  Error = 191.264737
# Epoch 308:  Error = 191.290967
# Epoch 309:  Error = 191.317048
# Epoch 310:  Error = 191.342981
# Epoch 311:  Error = 191.368767
# Epoch 312:  Error = 191.394409
# Epoch 313:  Error = 191.419907
# Epoch 314:  Error = 191.445261
# Epoch 315:  Error = 191.470474
# Epoch 316:  Error = 191.495546
# Epoch 317:  Error = 191.520479
# Epoch 318:  Error = 191.545273
# Epoch 319:  Error = 191.569929
# Epoch 320:  Error = 191.594450
# Epoch 321:  Error = 191.618835
# Epoch 322:  Error = 191.643085
# Epoch 323:  Error = 191.667203
# Epoch 324:  Error = 191.691188
# Epoch 325:  Error = 191.715043
# Epoch 326:  Error = 191.738767
# Epoch 327:  Error = 191.762362
# Epoch 328:  Error = 191.785829
# Epoch 329:  Error = 191.809169
# Epoch 330:  Error = 191.832382
# Epoch 331:  Error = 191.855471
# Epoch 332:  Error = 191.878435
# Epoch 333:  Error = 191.901276
# Epoch 334:  Error = 191.923994
# Epoch 335:  Error = 191.946591
# Epoch 336:  Error = 191.969068
# Epoch 337:  Error = 191.991425
# Epoch 338:  Error = 192.013663
# Epoch 339:  Error = 192.035783
# Epoch 340:  Error = 192.057787
# Epoch 341:  Error = 192.079674
# Epoch 342:  Error = 192.101446
# Epoch 343:  Error = 192.123104
# Epoch 344:  Error = 192.144648
# Epoch 345:  Error = 192.166080
# Epoch 346:  Error = 192.187400
# Epoch 347:  Error = 192.208609
# Epoch 348:  Error = 192.229708
# Epoch 349:  Error = 192.250697
# Epoch 350:  Error = 192.271578
# Epoch 351:  Error = 192.292351
# Epoch 352:  Error = 192.313017
# Epoch 353:  Error = 192.333577
# Epoch 354:  Error = 192.354032
# Epoch 355:  Error = 192.374382
# Epoch 356:  Error = 192.394628
# Epoch 357:  Error = 192.414772
# Epoch 358:  Error = 192.434812
# Epoch 359:  Error = 192.454752
# Epoch 360:  Error = 192.474590
# Epoch 361:  Error = 192.494328
# Epoch 362:  Error = 192.513967
# Epoch 363:  Error = 192.533507
# Epoch 364:  Error = 192.552949
# Epoch 365:  Error = 192.572294
# Epoch 366:  Error = 192.591542
# Epoch 367:  Error = 192.610694
# Epoch 368:  Error = 192.629751
# Epoch 369:  Error = 192.648714
# Epoch 370:  Error = 192.667582
# Epoch 371:  Error = 192.686358
# Epoch 372:  Error = 192.705041
# Epoch 373:  Error = 192.723631
# Epoch 374:  Error = 192.742131
# Epoch 375:  Error = 192.760540
# Epoch 376:  Error = 192.778859
# Epoch 377:  Error = 192.797089
# Epoch 378:  Error = 192.815230
# Epoch 379:  Error = 192.833283
# Epoch 380:  Error = 192.851249
# Epoch 381:  Error = 192.869127
# Epoch 382:  Error = 192.886920
# Epoch 383:  Error = 192.904626
# Epoch 384:  Error = 192.922248
# Epoch 385:  Error = 192.939785
# Epoch 386:  Error = 192.957238
# Epoch 387:  Error = 192.974608
# Epoch 388:  Error = 192.991895
# Epoch 389:  Error = 193.009100
# Epoch 390:  Error = 193.026223
# Epoch 391:  Error = 193.043266
# Epoch 392:  Error = 193.060227
# Epoch 393:  Error = 193.077109
# Epoch 394:  Error = 193.093911
# Epoch 395:  Error = 193.110635
# Epoch 396:  Error = 193.127280
# Epoch 397:  Error = 193.143847
# Epoch 398:  Error = 193.160337
# Epoch 399:  Error = 193.176750
# Epoch 400:  Error = 193.193087
# Epoch 401:  Error = 193.209348
# Epoch 402:  Error = 193.225534
# Epoch 403:  Error = 193.241645
# Epoch 404:  Error = 193.257682
# Epoch 405:  Error = 193.273645
# Epoch 406:  Error = 193.289535
# Epoch 407:  Error = 193.305352
# Epoch 408:  Error = 193.321096
# Epoch 409:  Error = 193.336769
# Epoch 410:  Error = 193.352371
# Epoch 411:  Error = 193.367902
# Epoch 412:  Error = 193.383362
# Epoch 413:  Error = 193.398752
# Epoch 414:  Error = 193.414073
# Epoch 415:  Error = 193.429325
# Epoch 416:  Error = 193.444508
# Epoch 417:  Error = 193.459624
# Epoch 418:  Error = 193.474671
# Epoch 419:  Error = 193.489651
# Epoch 420:  Error = 193.504565
# Epoch 421:  Error = 193.519411
# Epoch 422:  Error = 193.534193
# Epoch 423:  Error = 193.548908
# Epoch 424:  Error = 193.563558
# Epoch 425:  Error = 193.578144
# Epoch 426:  Error = 193.592665
# Epoch 427:  Error = 193.607123
# Epoch 428:  Error = 193.621517
# Epoch 429:  Error = 193.635848
# Epoch 430:  Error = 193.650116
# Epoch 431:  Error = 193.664322
# Epoch 432:  Error = 193.678467
# Epoch 433:  Error = 193.692549
# Epoch 434:  Error = 193.706571
# Epoch 435:  Error = 193.720532
# Epoch 436:  Error = 193.734433
# Epoch 437:  Error = 193.748274
# Epoch 438:  Error = 193.762055
# Epoch 439:  Error = 193.775777
# Epoch 440:  Error = 193.789440
# Epoch 441:  Error = 193.803045
# Epoch 442:  Error = 193.816591
# Epoch 443:  Error = 193.830080
# Epoch 444:  Error = 193.843512
# Epoch 445:  Error = 193.856886
# Epoch 446:  Error = 193.870204
# Epoch 447:  Error = 193.883466
# Epoch 448:  Error = 193.896671
# Epoch 449:  Error = 193.909821
# Epoch 450:  Error = 193.922916
# Epoch 451:  Error = 193.935956
# Epoch 452:  Error = 193.948941
# Epoch 453:  Error = 193.961872
# Epoch 454:  Error = 193.974749
# Epoch 455:  Error = 193.987572
# Epoch 456:  Error = 194.000342
# Epoch 457:  Error = 194.013059
# Epoch 458:  Error = 194.025724
# Epoch 459:  Error = 194.038336
# Epoch 460:  Error = 194.050896
# Epoch 461:  Error = 194.063404
# Epoch 462:  Error = 194.075861
# Epoch 463:  Error = 194.088267
# Epoch 464:  Error = 194.100623
# Epoch 465:  Error = 194.112927
# Epoch 466:  Error = 194.125182
# Epoch 467:  Error = 194.137387
# Epoch 468:  Error = 194.149542
# Epoch 469:  Error = 194.161648
# Epoch 470:  Error = 194.173705
# Epoch 471:  Error = 194.185713
# Epoch 472:  Error = 194.197673
# Epoch 473:  Error = 194.209584
# Epoch 474:  Error = 194.221448
# Epoch 475:  Error = 194.233265
# Epoch 476:  Error = 194.245034
# Epoch 477:  Error = 194.256756
# Epoch 478:  Error = 194.268431
# Epoch 479:  Error = 194.280060
# Epoch 480:  Error = 194.291642
# Epoch 481:  Error = 194.303179
# Epoch 482:  Error = 194.314670
# Epoch 483:  Error = 194.326116
# Epoch 484:  Error = 194.337517
# Epoch 485:  Error = 194.348873
# Epoch 486:  Error = 194.360184
# Epoch 487:  Error = 194.371451
# Epoch 488:  Error = 194.382673
# Epoch 489:  Error = 194.393852
# Epoch 490:  Error = 194.404988
# Epoch 491:  Error = 194.416080
# Epoch 492:  Error = 194.427129
# Epoch 493:  Error = 194.438135
# Epoch 494:  Error = 194.449098
# Epoch 495:  Error = 194.460020
# Epoch 496:  Error = 194.470899
# Epoch 497:  Error = 194.481736
# Epoch 498:  Error = 194.492531
# Epoch 499:  Error = 194.503286
# Epoch 500:  Error = 194.513999
# Epoch 501:  Error = 194.524671
# Epoch 502:  Error = 194.535302
# Epoch 503:  Error = 194.545893
# Epoch 504:  Error = 194.556443
# Epoch 505:  Error = 194.566954
# Epoch 506:  Error = 194.577425
# Epoch 507:  Error = 194.587856
# Epoch 508:  Error = 194.598248
# Epoch 509:  Error = 194.608600
# Epoch 510:  Error = 194.618914
# Epoch 511:  Error = 194.629189
# Epoch 512:  Error = 194.639426
# Epoch 513:  Error = 194.649624
# Epoch 514:  Error = 194.659784
# Epoch 515:  Error = 194.669907
# Epoch 516:  Error = 194.679991
# Epoch 517:  Error = 194.690039
# Epoch 518:  Error = 194.700049
# Epoch 519:  Error = 194.710021
# Epoch 520:  Error = 194.719958
# Epoch 521:  Error = 194.729857
# Epoch 522:  Error = 194.739720
# Epoch 523:  Error = 194.749547
# Epoch 524:  Error = 194.759338
# Epoch 525:  Error = 194.769092
# Epoch 526:  Error = 194.778812
# Epoch 527:  Error = 194.788495
# Epoch 528:  Error = 194.798144
# Epoch 529:  Error = 194.807757
# Epoch 530:  Error = 194.817336
# Epoch 531:  Error = 194.826879
# Epoch 532:  Error = 194.836389
# Epoch 533:  Error = 194.845864
# Epoch 534:  Error = 194.855304
# Epoch 535:  Error = 194.864711
# Epoch 536:  Error = 194.874084
# Epoch 537:  Error = 194.883423
# Epoch 538:  Error = 194.892729
# Epoch 539:  Error = 194.902002
# Epoch 540:  Error = 194.911242
# Epoch 541:  Error = 194.920448
# Epoch 542:  Error = 194.929622
# Epoch 543:  Error = 194.938763
# Epoch 544:  Error = 194.947872
# Epoch 545:  Error = 194.956949
# Epoch 546:  Error = 194.965994
# Epoch 547:  Error = 194.975006
# Epoch 548:  Error = 194.983987
# Epoch 549:  Error = 194.992937
# Epoch 550:  Error = 195.001855
# Epoch 551:  Error = 195.010742
# Epoch 552:  Error = 195.019598
# Epoch 553:  Error = 195.028422
# Epoch 554:  Error = 195.037217
# Epoch 555:  Error = 195.045980
# Epoch 556:  Error = 195.054713
# Epoch 557:  Error = 195.063416
# Epoch 558:  Error = 195.072089
# Epoch 559:  Error = 195.080731
# Epoch 560:  Error = 195.089344
# Epoch 561:  Error = 195.097927
# Epoch 562:  Error = 195.106481
# Epoch 563:  Error = 195.115005
# Epoch 564:  Error = 195.123501
# Epoch 565:  Error = 195.131967
# Epoch 566:  Error = 195.140404
# Epoch 567:  Error = 195.148812
# Epoch 568:  Error = 195.157192
# Epoch 569:  Error = 195.165543
# Epoch 570:  Error = 195.173866
# Epoch 571:  Error = 195.182161
# Epoch 572:  Error = 195.190427
# Epoch 573:  Error = 195.198666
# Epoch 574:  Error = 195.206877
# Epoch 575:  Error = 195.215060
# Epoch 576:  Error = 195.223216
# Epoch 577:  Error = 195.231344
# Epoch 578:  Error = 195.239446
# Epoch 579:  Error = 195.247520
# Epoch 580:  Error = 195.255567
# Epoch 581:  Error = 195.263587
# Epoch 582:  Error = 195.271581
# Epoch 583:  Error = 195.279548
# Epoch 584:  Error = 195.287489
# Epoch 585:  Error = 195.295403
# Epoch 586:  Error = 195.303291
# Epoch 587:  Error = 195.311153
# Epoch 588:  Error = 195.318989
# Epoch 589:  Error = 195.326800
# Epoch 590:  Error = 195.334585
# Epoch 591:  Error = 195.342344
# Epoch 592:  Error = 195.350078
# Epoch 593:  Error = 195.357786
# Epoch 594:  Error = 195.365469
# Epoch 595:  Error = 195.373128
# Epoch 596:  Error = 195.380761
# Epoch 597:  Error = 195.388370
# Epoch 598:  Error = 195.395954
# Epoch 599:  Error = 195.403513
# Epoch 600:  Error = 195.411048
# Epoch 601:  Error = 195.418558
# Epoch 602:  Error = 195.426045
# Epoch 603:  Error = 195.433507
# Epoch 604:  Error = 195.440945
# Epoch 605:  Error = 195.448360
# Epoch 606:  Error = 195.455750
# Epoch 607:  Error = 195.463117
# Epoch 608:  Error = 195.470461
# Epoch 609:  Error = 195.477781
# Epoch 610:  Error = 195.485077
# Epoch 611:  Error = 195.492351
# Epoch 612:  Error = 195.499601
# Epoch 613:  Error = 195.506829
# Epoch 614:  Error = 195.514033
# Epoch 615:  Error = 195.521215
# Epoch 616:  Error = 195.528374
# Epoch 617:  Error = 195.535511
# Epoch 618:  Error = 195.542625
# Epoch 619:  Error = 195.549717
# Epoch 620:  Error = 195.556787
# Epoch 621:  Error = 195.563834
# Epoch 622:  Error = 195.570859
# Epoch 623:  Error = 195.577863
# Epoch 624:  Error = 195.584845
# Epoch 625:  Error = 195.591805
# Epoch 626:  Error = 195.598743
# Epoch 627:  Error = 195.605660
# Epoch 628:  Error = 195.612555
# Epoch 629:  Error = 195.619429
# Epoch 630:  Error = 195.626282
# Epoch 631:  Error = 195.633114
# Epoch 632:  Error = 195.639924
# Epoch 633:  Error = 195.646714
# Epoch 634:  Error = 195.653483
# Epoch 635:  Error = 195.660231
# Epoch 636:  Error = 195.666959
# Epoch 637:  Error = 195.673665
# Epoch 638:  Error = 195.680352
# Epoch 639:  Error = 195.687018
# Epoch 640:  Error = 195.693664
# Epoch 641:  Error = 195.700289
# Epoch 642:  Error = 195.706895
# Epoch 643:  Error = 195.713480
# Epoch 644:  Error = 195.720046
# Epoch 645:  Error = 195.726592
# Epoch 646:  Error = 195.733118
# Epoch 647:  Error = 195.739624
# Epoch 648:  Error = 195.746111
# Epoch 649:  Error = 195.752578
# Epoch 650:  Error = 195.759026
# Epoch 651:  Error = 195.765455
# Epoch 652:  Error = 195.771864
# Epoch 653:  Error = 195.778255
# Epoch 654:  Error = 195.784626
# Epoch 655:  Error = 195.790978
# Epoch 656:  Error = 195.797312
# Epoch 657:  Error = 195.803627
# Epoch 658:  Error = 195.809922
# Epoch 659:  Error = 195.816200
# Epoch 660:  Error = 195.822459
# Epoch 661:  Error = 195.828699
# Epoch 662:  Error = 195.834921
# Epoch 663:  Error = 195.841124
# Epoch 664:  Error = 195.847310
# Epoch 665:  Error = 195.853477
# Epoch 666:  Error = 195.859626
# Epoch 667:  Error = 195.865758
# Epoch 668:  Error = 195.871871
# Epoch 669:  Error = 195.877966
# Epoch 670:  Error = 195.884044
# Epoch 671:  Error = 195.890104
# Epoch 672:  Error = 195.896147
# Epoch 673:  Error = 195.902172
# Epoch 674:  Error = 195.908179
# Epoch 675:  Error = 195.914169
# Epoch 676:  Error = 195.920142
# Epoch 677:  Error = 195.926098
# Epoch 678:  Error = 195.932036
# Epoch 679:  Error = 195.937958
# Epoch 680:  Error = 195.943862
# Epoch 681:  Error = 195.949749
# Epoch 682:  Error = 195.955620
# Epoch 683:  Error = 195.961474
# Epoch 684:  Error = 195.967311
# Epoch 685:  Error = 195.973132
# Epoch 686:  Error = 195.978935
# Epoch 687:  Error = 195.984723
# Epoch 688:  Error = 195.990494
# Epoch 689:  Error = 195.996249
# Epoch 690:  Error = 196.001987
# Epoch 691:  Error = 196.007709
# Epoch 692:  Error = 196.013415
# Epoch 693:  Error = 196.019105
# Epoch 694:  Error = 196.024779
# Epoch 695:  Error = 196.030437
# Epoch 696:  Error = 196.036079
# Epoch 697:  Error = 196.041705
# Epoch 698:  Error = 196.047315
# Epoch 699:  Error = 196.052910
# Epoch 700:  Error = 196.058489
# Epoch 701:  Error = 196.064053
# Epoch 702:  Error = 196.069601
# Epoch 703:  Error = 196.075134
# Epoch 704:  Error = 196.080651
# Epoch 705:  Error = 196.086153
# Epoch 706:  Error = 196.091640
# Epoch 707:  Error = 196.097111
# Epoch 708:  Error = 196.102568
# Epoch 709:  Error = 196.108009
# Epoch 710:  Error = 196.113436
# Epoch 711:  Error = 196.118848
# Epoch 712:  Error = 196.124244
# Epoch 713:  Error = 196.129626
# Epoch 714:  Error = 196.134993
# Epoch 715:  Error = 196.140346
# Epoch 716:  Error = 196.145684
# Epoch 717:  Error = 196.151007
# Epoch 718:  Error = 196.156316
# Epoch 719:  Error = 196.161610
# Epoch 720:  Error = 196.166890
# Epoch 721:  Error = 196.172156
# Epoch 722:  Error = 196.177407
# Epoch 723:  Error = 196.182644
# Epoch 724:  Error = 196.187867
# Epoch 725:  Error = 196.193076
# Epoch 726:  Error = 196.198271
# Epoch 727:  Error = 196.203452
# Epoch 728:  Error = 196.208619
# Epoch 729:  Error = 196.213772
# Epoch 730:  Error = 196.218911
# Epoch 731:  Error = 196.224037
# Epoch 732:  Error = 196.229148
# Epoch 733:  Error = 196.234247
# Epoch 734:  Error = 196.239331
# Epoch 735:  Error = 196.244402
# Epoch 736:  Error = 196.249460
# Epoch 737:  Error = 196.254504
# Epoch 738:  Error = 196.259534
# Epoch 739:  Error = 196.264552
# Epoch 740:  Error = 196.269556
# Epoch 741:  Error = 196.274547
# Epoch 742:  Error = 196.279525
# Epoch 743:  Error = 196.284489
# Epoch 744:  Error = 196.289441
# Epoch 745:  Error = 196.294379
# Epoch 746:  Error = 196.299305
# Epoch 747:  Error = 196.304217
# Epoch 748:  Error = 196.309117
# Epoch 749:  Error = 196.314004
# Epoch 750:  Error = 196.318878
# Epoch 751:  Error = 196.323740
# Epoch 752:  Error = 196.328588
# Epoch 753:  Error = 196.333425
# Epoch 754:  Error = 196.338248
# Epoch 755:  Error = 196.343059
# Epoch 756:  Error = 196.347858
# Epoch 757:  Error = 196.352644
# Epoch 758:  Error = 196.357418
# Epoch 759:  Error = 196.362180
# Epoch 760:  Error = 196.366929
# Epoch 761:  Error = 196.371666
# Epoch 762:  Error = 196.376391
# Epoch 763:  Error = 196.381103
# Epoch 764:  Error = 196.385804
# Epoch 765:  Error = 196.390493
# Epoch 766:  Error = 196.395169
# Epoch 767:  Error = 196.399834
# Epoch 768:  Error = 196.404487
# Epoch 769:  Error = 196.409127
# Epoch 770:  Error = 196.413756
# Epoch 771:  Error = 196.418374
# Epoch 772:  Error = 196.422979
# Epoch 773:  Error = 196.427573
# Epoch 774:  Error = 196.432155
# Epoch 775:  Error = 196.436726
# Epoch 776:  Error = 196.441285
# Epoch 777:  Error = 196.445833
# Epoch 778:  Error = 196.450369
# Epoch 779:  Error = 196.454893
# Epoch 780:  Error = 196.459407
# Epoch 781:  Error = 196.463909
# Epoch 782:  Error = 196.468400
# Epoch 783:  Error = 196.472879
# Epoch 784:  Error = 196.477347
# Epoch 785:  Error = 196.481804
# Epoch 786:  Error = 196.486250
# Epoch 787:  Error = 196.490685
# Epoch 788:  Error = 196.495109
# Epoch 789:  Error = 196.499522
# Epoch 790:  Error = 196.503924
# Epoch 791:  Error = 196.508315
# Epoch 792:  Error = 196.512695
# Epoch 793:  Error = 196.517064
# Epoch 794:  Error = 196.521422
# Epoch 795:  Error = 196.525770
# Epoch 796:  Error = 196.530107
# Epoch 797:  Error = 196.534433
# Epoch 798:  Error = 196.538749
# Epoch 799:  Error = 196.543054
# Epoch 800:  Error = 196.547349
# Epoch 801:  Error = 196.551633
# Epoch 802:  Error = 196.555906
# Epoch 803:  Error = 196.560169
# Epoch 804:  Error = 196.564422
# Epoch 805:  Error = 196.568664
# Epoch 806:  Error = 196.572896
# Epoch 807:  Error = 196.577118
# Epoch 808:  Error = 196.581329
# Epoch 809:  Error = 196.585530
# Epoch 810:  Error = 196.589721
# Epoch 811:  Error = 196.593902
# Epoch 812:  Error = 196.598073
# Epoch 813:  Error = 196.602234
# Epoch 814:  Error = 196.606384
# Epoch 815:  Error = 196.610525
# Epoch 816:  Error = 196.614656
# Epoch 817:  Error = 196.618776
# Epoch 818:  Error = 196.622887
# Epoch 819:  Error = 196.626988
# Epoch 820:  Error = 196.631079
# Epoch 821:  Error = 196.635161
# Epoch 822:  Error = 196.639232
# Epoch 823:  Error = 196.643294
# Epoch 824:  Error = 196.647347
# Epoch 825:  Error = 196.651389
# Epoch 826:  Error = 196.655422
# Epoch 827:  Error = 196.659446
# Epoch 828:  Error = 196.663460
# Epoch 829:  Error = 196.667464
# Epoch 830:  Error = 196.671459
# Epoch 831:  Error = 196.675444
# Epoch 832:  Error = 196.679420
# Epoch 833:  Error = 196.683387
# Epoch 834:  Error = 196.687344
# Epoch 835:  Error = 196.691292
# Epoch 836:  Error = 196.695231
# Epoch 837:  Error = 196.699160
# Epoch 838:  Error = 196.703081
# Epoch 839:  Error = 196.706992
# Epoch 840:  Error = 196.710894
# Epoch 841:  Error = 196.714787
# Epoch 842:  Error = 196.718670
# Epoch 843:  Error = 196.722545
# Epoch 844:  Error = 196.726411
# Epoch 845:  Error = 196.730267
# Epoch 846:  Error = 196.734115
# Epoch 847:  Error = 196.737954
# Epoch 848:  Error = 196.741784
# Epoch 849:  Error = 196.745605
# Epoch 850:  Error = 196.749417
# Epoch 851:  Error = 196.753220
# Epoch 852:  Error = 196.757015
# Epoch 853:  Error = 196.760801
# Epoch 854:  Error = 196.764578
# Epoch 855:  Error = 196.768347
# Epoch 856:  Error = 196.772106
# Epoch 857:  Error = 196.775858
# Epoch 858:  Error = 196.779600
# Epoch 859:  Error = 196.783334
# Epoch 860:  Error = 196.787060
# Epoch 861:  Error = 196.790777
# Epoch 862:  Error = 196.794485
# Epoch 863:  Error = 196.798185
# Epoch 864:  Error = 196.801877
# Epoch 865:  Error = 196.805560
# Epoch 866:  Error = 196.809235
# Epoch 867:  Error = 196.812902
# Epoch 868:  Error = 196.816560
# Epoch 869:  Error = 196.820210
# Epoch 870:  Error = 196.823852
# Epoch 871:  Error = 196.827485
# Epoch 872:  Error = 196.831111
# Epoch 873:  Error = 196.834728
# Epoch 874:  Error = 196.838337
# Epoch 875:  Error = 196.841938
# Epoch 876:  Error = 196.845530
# Epoch 877:  Error = 196.849115
# Epoch 878:  Error = 196.852692
# Epoch 879:  Error = 196.856261
# Epoch 880:  Error = 196.859821
# Epoch 881:  Error = 196.863374
# Epoch 882:  Error = 196.866919
# Epoch 883:  Error = 196.870456
# Epoch 884:  Error = 196.873985
# Epoch 885:  Error = 196.877506
# Epoch 886:  Error = 196.881020
# Epoch 887:  Error = 196.884526
# Epoch 888:  Error = 196.888023
# Epoch 889:  Error = 196.891514
# Epoch 890:  Error = 196.894996
# Epoch 891:  Error = 196.898471
# Epoch 892:  Error = 196.901938
# Epoch 893:  Error = 196.905397
# Epoch 894:  Error = 196.908849
# Epoch 895:  Error = 196.912293
# Epoch 896:  Error = 196.915730
# Epoch 897:  Error = 196.919159
# Epoch 898:  Error = 196.922581
# Epoch 899:  Error = 196.925995
# Epoch 900:  Error = 196.929402
# Epoch 901:  Error = 196.932801
# Epoch 902:  Error = 196.936193
# Epoch 903:  Error = 196.939577
# Epoch 904:  Error = 196.942954
# Epoch 905:  Error = 196.946324
# Epoch 906:  Error = 196.949686
# Epoch 907:  Error = 196.953041
# Epoch 908:  Error = 196.956389
# Epoch 909:  Error = 196.959730
# Epoch 910:  Error = 196.963063
# Epoch 911:  Error = 196.966389
# Epoch 912:  Error = 196.969708
# Epoch 913:  Error = 196.973020
# Epoch 914:  Error = 196.976325
# Epoch 915:  Error = 196.979622
# Epoch 916:  Error = 196.982913
# Epoch 917:  Error = 196.986196
# Epoch 918:  Error = 196.989473
# Epoch 919:  Error = 196.992742
# Epoch 920:  Error = 196.996004
# Epoch 921:  Error = 196.999260
# Epoch 922:  Error = 197.002508
# Epoch 923:  Error = 197.005750
# Epoch 924:  Error = 197.008984
# Epoch 925:  Error = 197.012212
# Epoch 926:  Error = 197.015433
# Epoch 927:  Error = 197.018647
# Epoch 928:  Error = 197.021854
# Epoch 929:  Error = 197.025054
# Epoch 930:  Error = 197.028248
# Epoch 931:  Error = 197.031435
# Epoch 932:  Error = 197.034615
# Epoch 933:  Error = 197.037788
# Epoch 934:  Error = 197.040955
# Epoch 935:  Error = 197.044115
# Epoch 936:  Error = 197.047269
# Epoch 937:  Error = 197.050415
# Epoch 938:  Error = 197.053556
# Epoch 939:  Error = 197.056689
# Epoch 940:  Error = 197.059816
# Epoch 941:  Error = 197.062937
# Epoch 942:  Error = 197.066051
# Epoch 943:  Error = 197.069158
# Epoch 944:  Error = 197.072259
# Epoch 945:  Error = 197.075353
# Epoch 946:  Error = 197.078441
# Epoch 947:  Error = 197.081523
# Epoch 948:  Error = 197.084598
# Epoch 949:  Error = 197.087667
# Epoch 950:  Error = 197.090730
# Epoch 951:  Error = 197.093786
# Epoch 952:  Error = 197.096836
# Epoch 953:  Error = 197.099879
# Epoch 954:  Error = 197.102916
# Epoch 955:  Error = 197.105947
# Epoch 956:  Error = 197.108972
# Epoch 957:  Error = 197.111990
# Epoch 958:  Error = 197.115003
# Epoch 959:  Error = 197.118009
# Epoch 960:  Error = 197.121009
# Epoch 961:  Error = 197.124002
# Epoch 962:  Error = 197.126990
# Epoch 963:  Error = 197.129972
# Epoch 964:  Error = 197.132947
# Epoch 965:  Error = 197.135916
# Epoch 966:  Error = 197.138880
# Epoch 967:  Error = 197.141837
# Epoch 968:  Error = 197.144788
# Epoch 969:  Error = 197.147733
# Epoch 970:  Error = 197.150673
# Epoch 971:  Error = 197.153606
# Epoch 972:  Error = 197.156533
# Epoch 973:  Error = 197.159455
# Epoch 974:  Error = 197.162370
# Epoch 975:  Error = 197.165280
# Epoch 976:  Error = 197.168183
# Epoch 977:  Error = 197.171081
# Epoch 978:  Error = 197.173973
# Epoch 979:  Error = 197.176859
# Epoch 980:  Error = 197.179740
# Epoch 981:  Error = 197.182614
# Epoch 982:  Error = 197.185483
# Epoch 983:  Error = 197.188346
# Epoch 984:  Error = 197.191204
# Epoch 985:  Error = 197.194055
# Epoch 986:  Error = 197.196901
# Epoch 987:  Error = 197.199741
# Epoch 988:  Error = 197.202576
# Epoch 989:  Error = 197.205405
# Epoch 990:  Error = 197.208228
# Epoch 991:  Error = 197.211046
# Epoch 992:  Error = 197.213858
# Epoch 993:  Error = 197.216664
# Epoch 994:  Error = 197.219465
# Epoch 995:  Error = 197.222261
# Epoch 996:  Error = 197.225050
# Epoch 997:  Error = 197.227835
# Epoch 998:  Error = 197.230614
# Epoch 999:  Error = 197.233387
# Epoch 1000:  Error = 197.236155
# Epoch 1001:  Error = 197.238917
# Epoch 1002:  Error = 197.241674
# Epoch 1003:  Error = 197.244426
# Epoch 1004:  Error = 197.247172
# Epoch 1005:  Error = 197.249912
# Epoch 1006:  Error = 197.252648
# Epoch 1007:  Error = 197.255378
# Epoch 1008:  Error = 197.258103
# Epoch 1009:  Error = 197.260822
# Epoch 1010:  Error = 197.263536
# Epoch 1011:  Error = 197.266245
# Epoch 1012:  Error = 197.268948
# Epoch 1013:  Error = 197.271646
# Epoch 1014:  Error = 197.274339
# Epoch 1015:  Error = 197.277027
# Epoch 1016:  Error = 197.279709
# Epoch 1017:  Error = 197.282387
# Epoch 1018:  Error = 197.285059
# Epoch 1019:  Error = 197.287726
# Epoch 1020:  Error = 197.290388
# Epoch 1021:  Error = 197.293044
# Epoch 1022:  Error = 197.295696
# Epoch 1023:  Error = 197.298342
# Epoch 1024:  Error = 197.300983
# Epoch 1025:  Error = 197.303620
# Epoch 1026:  Error = 197.306251
# Epoch 1027:  Error = 197.308877
# Epoch 1028:  Error = 197.311498
# Epoch 1029:  Error = 197.314114
# Epoch 1030:  Error = 197.316725
# Epoch 1031:  Error = 197.319331
# Epoch 1032:  Error = 197.321932
# Epoch 1033:  Error = 197.324528
# Epoch 1034:  Error = 197.327119
# Epoch 1035:  Error = 197.329705
# Epoch 1036:  Error = 197.332287
# Epoch 1037:  Error = 197.334863
# Epoch 1038:  Error = 197.337434
# Epoch 1039:  Error = 197.340001
# Epoch 1040:  Error = 197.342563
# Epoch 1041:  Error = 197.345119
# Epoch 1042:  Error = 197.347671
# Epoch 1043:  Error = 197.350218
# Epoch 1044:  Error = 197.352761
# Epoch 1045:  Error = 197.355298
# Epoch 1046:  Error = 197.357831
# Epoch 1047:  Error = 197.360359
# Epoch 1048:  Error = 197.362882
# Epoch 1049:  Error = 197.365401
# Epoch 1050:  Error = 197.367914
# Epoch 1051:  Error = 197.370423
# Epoch 1052:  Error = 197.372928
# Epoch 1053:  Error = 197.375427
# Epoch 1054:  Error = 197.377922
# Epoch 1055:  Error = 197.380412
# Epoch 1056:  Error = 197.382898
# Epoch 1057:  Error = 197.385379
# Epoch 1058:  Error = 197.387855
# Epoch 1059:  Error = 197.390327
# Epoch 1060:  Error = 197.392794
# Epoch 1061:  Error = 197.395257
# Epoch 1062:  Error = 197.397715
# Epoch 1063:  Error = 197.400168
# Epoch 1064:  Error = 197.402617
# Epoch 1065:  Error = 197.405061
# Epoch 1066:  Error = 197.407501
# Epoch 1067:  Error = 197.409936
# Epoch 1068:  Error = 197.412367
# Epoch 1069:  Error = 197.414793
# Epoch 1070:  Error = 197.417215
# Epoch 1071:  Error = 197.419632
# Epoch 1072:  Error = 197.422045
# Epoch 1073:  Error = 197.424453
# Epoch 1074:  Error = 197.426857
# Epoch 1075:  Error = 197.429257
# Epoch 1076:  Error = 197.431652
# Epoch 1077:  Error = 197.434043
# Epoch 1078:  Error = 197.436429
# Epoch 1079:  Error = 197.438811
# Epoch 1080:  Error = 197.441189
# Epoch 1081:  Error = 197.443562
# Epoch 1082:  Error = 197.445931
# Epoch 1083:  Error = 197.448296
# Epoch 1084:  Error = 197.450656
# Epoch 1085:  Error = 197.453012
# Epoch 1086:  Error = 197.455364
# Epoch 1087:  Error = 197.457712
# Epoch 1088:  Error = 197.460055
# Epoch 1089:  Error = 197.462394
# Epoch 1090:  Error = 197.464729
# Epoch 1091:  Error = 197.467059
# Epoch 1092:  Error = 197.469385
# Epoch 1093:  Error = 197.471708
# Epoch 1094:  Error = 197.474025
# Epoch 1095:  Error = 197.476339
# Epoch 1096:  Error = 197.478649
# Epoch 1097:  Error = 197.480954
# Epoch 1098:  Error = 197.483255
# Epoch 1099:  Error = 197.485553
# Epoch 1100:  Error = 197.487846
# Epoch 1101:  Error = 197.490134
# Epoch 1102:  Error = 197.492419
# Epoch 1103:  Error = 197.494700
# Epoch 1104:  Error = 197.496976
# Epoch 1105:  Error = 197.499249
# Epoch 1106:  Error = 197.501518
# Epoch 1107:  Error = 197.503782
# Epoch 1108:  Error = 197.506042
# Epoch 1109:  Error = 197.508299
# Epoch 1110:  Error = 197.510551
# Epoch 1111:  Error = 197.512799
# Epoch 1112:  Error = 197.515044
# Epoch 1113:  Error = 197.517284
# Epoch 1114:  Error = 197.519520
# Epoch 1115:  Error = 197.521753
# Epoch 1116:  Error = 197.523981
# Epoch 1117:  Error = 197.526206
# Epoch 1118:  Error = 197.528426
# Epoch 1119:  Error = 197.530643
# Epoch 1120:  Error = 197.532856
# Epoch 1121:  Error = 197.535065
# Epoch 1122:  Error = 197.537270
# Epoch 1123:  Error = 197.539471
# Epoch 1124:  Error = 197.541668
# Epoch 1125:  Error = 197.543861
# Epoch 1126:  Error = 197.546051
# Epoch 1127:  Error = 197.548237
# Epoch 1128:  Error = 197.550418
# Epoch 1129:  Error = 197.552596
# Epoch 1130:  Error = 197.554771
# Epoch 1131:  Error = 197.556941
# Epoch 1132:  Error = 197.559108
# Epoch 1133:  Error = 197.561270
# Epoch 1134:  Error = 197.563430
# Epoch 1135:  Error = 197.565585
# Epoch 1136:  Error = 197.567736
# Epoch 1137:  Error = 197.569884
# Epoch 1138:  Error = 197.572028
# Epoch 1139:  Error = 197.574169
# Epoch 1140:  Error = 197.576305
# Epoch 1141:  Error = 197.578438
# Epoch 1142:  Error = 197.580568
# Epoch 1143:  Error = 197.582693
# Epoch 1144:  Error = 197.584815
# Epoch 1145:  Error = 197.586933
# Epoch 1146:  Error = 197.589048
# Epoch 1147:  Error = 197.591159
# Epoch 1148:  Error = 197.593266
# Epoch 1149:  Error = 197.595370
# Epoch 1150:  Error = 197.597470
# Epoch 1151:  Error = 197.599566
# Epoch 1152:  Error = 197.601659
# Epoch 1153:  Error = 197.603748
# Epoch 1154:  Error = 197.605834
# Epoch 1155:  Error = 197.607916
# Epoch 1156:  Error = 197.609995
# Epoch 1157:  Error = 197.612070
# Epoch 1158:  Error = 197.614141
# Epoch 1159:  Error = 197.616209
# Epoch 1160:  Error = 197.618274
# Epoch 1161:  Error = 197.620334
# Epoch 1162:  Error = 197.622392
# Epoch 1163:  Error = 197.624446
# Epoch 1164:  Error = 197.626496
# Epoch 1165:  Error = 197.628543
# Epoch 1166:  Error = 197.630586
# Epoch 1167:  Error = 197.632626
# Epoch 1168:  Error = 197.634663
# Epoch 1169:  Error = 197.636696
# Epoch 1170:  Error = 197.638726
# Epoch 1171:  Error = 197.640752
# Epoch 1172:  Error = 197.642775
# Epoch 1173:  Error = 197.644794
# Epoch 1174:  Error = 197.646810
# Epoch 1175:  Error = 197.648822
# Epoch 1176:  Error = 197.650832
# Epoch 1177:  Error = 197.652838
# Epoch 1178:  Error = 197.654840
# Epoch 1179:  Error = 197.656839
# Epoch 1180:  Error = 197.658835
# Epoch 1181:  Error = 197.660827
# Epoch 1182:  Error = 197.662816
# Epoch 1183:  Error = 197.664802
# Epoch 1184:  Error = 197.666784
# Epoch 1185:  Error = 197.668764
# Epoch 1186:  Error = 197.670739
# Epoch 1187:  Error = 197.672712
# Epoch 1188:  Error = 197.674681
# Epoch 1189:  Error = 197.676647
# Epoch 1190:  Error = 197.678610
# Epoch 1191:  Error = 197.680569
# Epoch 1192:  Error = 197.682525
# Epoch 1193:  Error = 197.684478
# Epoch 1194:  Error = 197.686428
# Epoch 1195:  Error = 197.688374
# Epoch 1196:  Error = 197.690318
# Epoch 1197:  Error = 197.692258
# Epoch 1198:  Error = 197.694194
# Epoch 1199:  Error = 197.696128
# Epoch 1200:  Error = 197.698059
# Epoch 1201:  Error = 197.699986
# Epoch 1202:  Error = 197.701910
# Epoch 1203:  Error = 197.703831
# Epoch 1204:  Error = 197.705749
# Epoch 1205:  Error = 197.707663
# Epoch 1206:  Error = 197.709575
# Epoch 1207:  Error = 197.711483
# Epoch 1208:  Error = 197.713388
# Epoch 1209:  Error = 197.715290
# Epoch 1210:  Error = 197.717189
# Epoch 1211:  Error = 197.719085
# Epoch 1212:  Error = 197.720978
# Epoch 1213:  Error = 197.722868
# Epoch 1214:  Error = 197.724754
# Epoch 1215:  Error = 197.726638
# Epoch 1216:  Error = 197.728518
# Epoch 1217:  Error = 197.730396
# Epoch 1218:  Error = 197.732270
# Epoch 1219:  Error = 197.734141
# Epoch 1220:  Error = 197.736010
# Epoch 1221:  Error = 197.737875
# Epoch 1222:  Error = 197.739737
# Epoch 1223:  Error = 197.741596
# Epoch 1224:  Error = 197.743453
# Epoch 1225:  Error = 197.745306
# Epoch 1226:  Error = 197.747156
# Epoch 1227:  Error = 197.749003
# Epoch 1228:  Error = 197.750848
# Epoch 1229:  Error = 197.752689
# Epoch 1230:  Error = 197.754527
# Epoch 1231:  Error = 197.756363
# Epoch 1232:  Error = 197.758195
# Epoch 1233:  Error = 197.760024
# Epoch 1234:  Error = 197.761851
# Epoch 1235:  Error = 197.763675
# Epoch 1236:  Error = 197.765495
# Epoch 1237:  Error = 197.767313
# Epoch 1238:  Error = 197.769128
# Epoch 1239:  Error = 197.770940
# Epoch 1240:  Error = 197.772749
# Epoch 1241:  Error = 197.774555
# Epoch 1242:  Error = 197.776359
# Epoch 1243:  Error = 197.778159
# Epoch 1244:  Error = 197.779957
# Epoch 1245:  Error = 197.781751
# Epoch 1246:  Error = 197.783543
# Epoch 1247:  Error = 197.785332
# Epoch 1248:  Error = 197.787118
# Epoch 1249:  Error = 197.788902
# Epoch 1250:  Error = 197.790682
# Epoch 1251:  Error = 197.792460
# Epoch 1252:  Error = 197.794235
# Epoch 1253:  Error = 197.796007
# Epoch 1254:  Error = 197.797776
# Epoch 1255:  Error = 197.799543
# Epoch 1256:  Error = 197.801306
# Epoch 1257:  Error = 197.803067
# Epoch 1258:  Error = 197.804826
# Epoch 1259:  Error = 197.806581
# Epoch 1260:  Error = 197.808334
# Epoch 1261:  Error = 197.810083
# Epoch 1262:  Error = 197.811831
# Epoch 1263:  Error = 197.813575
# Epoch 1264:  Error = 197.815317
# Epoch 1265:  Error = 197.817056
# Epoch 1266:  Error = 197.818792
# Epoch 1267:  Error = 197.820525
# Epoch 1268:  Error = 197.822256
# Epoch 1269:  Error = 197.823984
# Epoch 1270:  Error = 197.825710
# Epoch 1271:  Error = 197.827432
# Epoch 1272:  Error = 197.829152
# Epoch 1273:  Error = 197.830870
# Epoch 1274:  Error = 197.832584
# Epoch 1275:  Error = 197.834296
# Epoch 1276:  Error = 197.836006
# Epoch 1277:  Error = 197.837712
# Epoch 1278:  Error = 197.839417
# Epoch 1279:  Error = 197.841118
# Epoch 1280:  Error = 197.842817
# Epoch 1281:  Error = 197.844513
# Epoch 1282:  Error = 197.846206
# Epoch 1283:  Error = 197.847897
# Epoch 1284:  Error = 197.849586
# Epoch 1285:  Error = 197.851271
# Epoch 1286:  Error = 197.852955
# Epoch 1287:  Error = 197.854635
# Epoch 1288:  Error = 197.856313
# Epoch 1289:  Error = 197.857988
# Epoch 1290:  Error = 197.859661
# Epoch 1291:  Error = 197.861331
# Epoch 1292:  Error = 197.862999
# Epoch 1293:  Error = 197.864664
# Epoch 1294:  Error = 197.866327
# Epoch 1295:  Error = 197.867987
# Epoch 1296:  Error = 197.869644
# Epoch 1297:  Error = 197.871299
# Epoch 1298:  Error = 197.872951
# Epoch 1299:  Error = 197.874601
# Epoch 1300:  Error = 197.876249
# Epoch 1301:  Error = 197.877894
# Epoch 1302:  Error = 197.879536
# Epoch 1303:  Error = 197.881176
# Epoch 1304:  Error = 197.882813
# Epoch 1305:  Error = 197.884448
# Epoch 1306:  Error = 197.886080
# Epoch 1307:  Error = 197.887710
# Epoch 1308:  Error = 197.889338
# Epoch 1309:  Error = 197.890963
# Epoch 1310:  Error = 197.892585
# Epoch 1311:  Error = 197.894205
# Epoch 1312:  Error = 197.895823
# Epoch 1313:  Error = 197.897438
# Epoch 1314:  Error = 197.899051
# Epoch 1315:  Error = 197.900661
# Epoch 1316:  Error = 197.902269
# Epoch 1317:  Error = 197.903875
# Epoch 1318:  Error = 197.905478
# Epoch 1319:  Error = 197.907079
# Epoch 1320:  Error = 197.908677
# Epoch 1321:  Error = 197.910273
# Epoch 1322:  Error = 197.911866
# Epoch 1323:  Error = 197.913457
# Epoch 1324:  Error = 197.915046
# Epoch 1325:  Error = 197.916632
# Epoch 1326:  Error = 197.918216
# Epoch 1327:  Error = 197.919798
# Epoch 1328:  Error = 197.921377
# Epoch 1329:  Error = 197.922954
# Epoch 1330:  Error = 197.924528
# Epoch 1331:  Error = 197.926100
# Epoch 1332:  Error = 197.927670
# Epoch 1333:  Error = 197.929238
# Epoch 1334:  Error = 197.930803
# Epoch 1335:  Error = 197.932366
# Epoch 1336:  Error = 197.933926
# Epoch 1337:  Error = 197.935484
# Epoch 1338:  Error = 197.937040
# Epoch 1339:  Error = 197.938594
# Epoch 1340:  Error = 197.940145
# Epoch 1341:  Error = 197.941694
# Epoch 1342:  Error = 197.943241
# Epoch 1343:  Error = 197.944785
# Epoch 1344:  Error = 197.946328
# Epoch 1345:  Error = 197.947867
# Epoch 1346:  Error = 197.949405
# Epoch 1347:  Error = 197.950940
# Epoch 1348:  Error = 197.952473
# Epoch 1349:  Error = 197.954004
# Epoch 1350:  Error = 197.955533
# Epoch 1351:  Error = 197.957059
# Epoch 1352:  Error = 197.958583
# Epoch 1353:  Error = 197.960105
# Epoch 1354:  Error = 197.961625
# Epoch 1355:  Error = 197.963142
# Epoch 1356:  Error = 197.964657
# Epoch 1357:  Error = 197.966170
# Epoch 1358:  Error = 197.967681
# Epoch 1359:  Error = 197.969190
# Epoch 1360:  Error = 197.970696
# Epoch 1361:  Error = 197.972200
# Epoch 1362:  Error = 197.973702
# Epoch 1363:  Error = 197.975202
# Epoch 1364:  Error = 197.976700
# Epoch 1365:  Error = 197.978195
# Epoch 1366:  Error = 197.979688
# Epoch 1367:  Error = 197.981179
# Epoch 1368:  Error = 197.982668
# Epoch 1369:  Error = 197.984155
# Epoch 1370:  Error = 197.985640
# Epoch 1371:  Error = 197.987122
# Epoch 1372:  Error = 197.988602
# Epoch 1373:  Error = 197.990081
# Epoch 1374:  Error = 197.991557
# Epoch 1375:  Error = 197.993031
# Epoch 1376:  Error = 197.994502
# Epoch 1377:  Error = 197.995972
# Epoch 1378:  Error = 197.997440
# Epoch 1379:  Error = 197.998905
# Epoch 1380:  Error = 198.000369
# Epoch 1381:  Error = 198.001830
# Epoch 1382:  Error = 198.003289
# Epoch 1383:  Error = 198.004746
# Epoch 1384:  Error = 198.006201
# Epoch 1385:  Error = 198.007654
# Epoch 1386:  Error = 198.009105
# Epoch 1387:  Error = 198.010553
# Epoch 1388:  Error = 198.012000
# Epoch 1389:  Error = 198.013445
# Epoch 1390:  Error = 198.014887
# Epoch 1391:  Error = 198.016328
# Epoch 1392:  Error = 198.017766
# Epoch 1393:  Error = 198.019202
# Epoch 1394:  Error = 198.020637
# Epoch 1395:  Error = 198.022069
# Epoch 1396:  Error = 198.023499
# Epoch 1397:  Error = 198.024927
# Epoch 1398:  Error = 198.026354
# Epoch 1399:  Error = 198.027778
# Epoch 1400:  Error = 198.029200
# Epoch 1401:  Error = 198.030620
# Epoch 1402:  Error = 198.032038
# Epoch 1403:  Error = 198.033454
# Epoch 1404:  Error = 198.034868
# Epoch 1405:  Error = 198.036281
# Epoch 1406:  Error = 198.037691
# Epoch 1407:  Error = 198.039099
# Epoch 1408:  Error = 198.040505
# Epoch 1409:  Error = 198.041909
# Epoch 1410:  Error = 198.043311
# Epoch 1411:  Error = 198.044712
# Epoch 1412:  Error = 198.046110
# Epoch 1413:  Error = 198.047506
# Epoch 1414:  Error = 198.048900
# Epoch 1415:  Error = 198.050293
# Epoch 1416:  Error = 198.051683
# Epoch 1417:  Error = 198.053072
# Epoch 1418:  Error = 198.054458
# Epoch 1419:  Error = 198.055843
# Epoch 1420:  Error = 198.057225
# Epoch 1421:  Error = 198.058606
# Epoch 1422:  Error = 198.059985
# Epoch 1423:  Error = 198.061362
# Epoch 1424:  Error = 198.062737
# Epoch 1425:  Error = 198.064110
# Epoch 1426:  Error = 198.065481
# Epoch 1427:  Error = 198.066850
# Epoch 1428:  Error = 198.068218
# Epoch 1429:  Error = 198.069583
# Epoch 1430:  Error = 198.070946
# Epoch 1431:  Error = 198.072308
# Epoch 1432:  Error = 198.073668
# Epoch 1433:  Error = 198.075026
# Epoch 1434:  Error = 198.076382
# Epoch 1435:  Error = 198.077736
# Epoch 1436:  Error = 198.079088
# Epoch 1437:  Error = 198.080438
# Epoch 1438:  Error = 198.081787
# Epoch 1439:  Error = 198.083134
# Epoch 1440:  Error = 198.084478
# Epoch 1441:  Error = 198.085821
# Epoch 1442:  Error = 198.087162
# Epoch 1443:  Error = 198.088502
# Epoch 1444:  Error = 198.089839
# Epoch 1445:  Error = 198.091174
# Epoch 1446:  Error = 198.092508
# Epoch 1447:  Error = 198.093840
# Epoch 1448:  Error = 198.095170
# Epoch 1449:  Error = 198.096498
# Epoch 1450:  Error = 198.097825
# Epoch 1451:  Error = 198.099149
# Epoch 1452:  Error = 198.100472
# Epoch 1453:  Error = 198.101793
# Epoch 1454:  Error = 198.103112
# Epoch 1455:  Error = 198.104430
# Epoch 1456:  Error = 198.105745
# Epoch 1457:  Error = 198.107059
# Epoch 1458:  Error = 198.108371
# Epoch 1459:  Error = 198.109681
# Epoch 1460:  Error = 198.110990
# Epoch 1461:  Error = 198.112296
# Epoch 1462:  Error = 198.113601
# Epoch 1463:  Error = 198.114904
# Epoch 1464:  Error = 198.116206
# Epoch 1465:  Error = 198.117505
# Epoch 1466:  Error = 198.118803
# Epoch 1467:  Error = 198.120099
# Epoch 1468:  Error = 198.121394
# Epoch 1469:  Error = 198.122686
# Epoch 1470:  Error = 198.123977
# Epoch 1471:  Error = 198.125266
# Epoch 1472:  Error = 198.126553
# Epoch 1473:  Error = 198.127839
# Epoch 1474:  Error = 198.129123
# Epoch 1475:  Error = 198.130405
# Epoch 1476:  Error = 198.131685
# Epoch 1477:  Error = 198.132964
# Epoch 1478:  Error = 198.134241
# Epoch 1479:  Error = 198.135516
# Epoch 1480:  Error = 198.136790
# Epoch 1481:  Error = 198.138062
# Epoch 1482:  Error = 198.139332
# Epoch 1483:  Error = 198.140600
# Epoch 1484:  Error = 198.141867
# Epoch 1485:  Error = 198.143132
# Epoch 1486:  Error = 198.144395
# Epoch 1487:  Error = 198.145657
# Epoch 1488:  Error = 198.146917
# Epoch 1489:  Error = 198.148175
# Epoch 1490:  Error = 198.149432
# Epoch 1491:  Error = 198.150687
# Epoch 1492:  Error = 198.151940
# Epoch 1493:  Error = 198.153191
# Epoch 1494:  Error = 198.154441
# Epoch 1495:  Error = 198.155690
# Epoch 1496:  Error = 198.156936
# Epoch 1497:  Error = 198.158181
# Epoch 1498:  Error = 198.159424
# Epoch 1499:  Error = 198.160666
# Epoch 1500:  Error = 198.161906
# Epoch 1501:  Error = 198.163145
# Epoch 1502:  Error = 198.164381
# Epoch 1503:  Error = 198.165616
# Epoch 1504:  Error = 198.166850
# Epoch 1505:  Error = 198.168082
# Epoch 1506:  Error = 198.169312
# Epoch 1507:  Error = 198.170540
# Epoch 1508:  Error = 198.171767
# Epoch 1509:  Error = 198.172993
# Epoch 1510:  Error = 198.174217
# Epoch 1511:  Error = 198.175439
# Epoch 1512:  Error = 198.176659
# Epoch 1513:  Error = 198.177878
# Epoch 1514:  Error = 198.179095
# Epoch 1515:  Error = 198.180311
# Epoch 1516:  Error = 198.181525
# Epoch 1517:  Error = 198.182738
# Epoch 1518:  Error = 198.183949
# Epoch 1519:  Error = 198.185158
# Epoch 1520:  Error = 198.186366
# Epoch 1521:  Error = 198.187572
# Epoch 1522:  Error = 198.188777
# Epoch 1523:  Error = 198.189980
# Epoch 1524:  Error = 198.191181
# Epoch 1525:  Error = 198.192381
# Epoch 1526:  Error = 198.193580
# Epoch 1527:  Error = 198.194776
# Epoch 1528:  Error = 198.195972
# Epoch 1529:  Error = 198.197165
# Epoch 1530:  Error = 198.198357
# ...
# Epoch 9500:  Error = 199.723370
# Epoch 9501:  Error = 199.723400
# Epoch 9502:  Error = 199.723430
# Epoch 9503:  Error = 199.723460
# Epoch 9504:  Error = 199.723490
# Epoch 9505:  Error = 199.723520
# Epoch 9506:  Error = 199.723550
# Epoch 9507:  Error = 199.723580
# Epoch 9508:  Error = 199.723610
# Epoch 9509:  Error = 199.723640
# Epoch 9510:  Error = 199.723670
# Epoch 9511:  Error = 199.723701
# Epoch 9512:  Error = 199.723731
# Epoch 9513:  Error = 199.723761
# Epoch 9514:  Error = 199.723791
# Epoch 9515:  Error = 199.723821
# Epoch 9516:  Error = 199.723851
# Epoch 9517:  Error = 199.723881
# Epoch 9518:  Error = 199.723911
# Epoch 9519:  Error = 199.723940
# Epoch 9520:  Error = 199.723970
# Epoch 9521:  Error = 199.724000
# Epoch 9522:  Error = 199.724030
# Epoch 9523:  Error = 199.724060
# Epoch 9524:  Error = 199.724090
# Epoch 9525:  Error = 199.724120
# Epoch 9526:  Error = 199.724150
# Epoch 9527:  Error = 199.724180
# Epoch 9528:  Error = 199.724210
# Epoch 9529:  Error = 199.724240
# Epoch 9530:  Error = 199.724270
# Epoch 9531:  Error = 199.724300
# Epoch 9532:  Error = 199.724330
# Epoch 9533:  Error = 199.724359
# Epoch 9534:  Error = 199.724389
# Epoch 9535:  Error = 199.724419
# Epoch 9536:  Error = 199.724449
# Epoch 9537:  Error = 199.724479
# Epoch 9538:  Error = 199.724509
# Epoch 9539:  Error = 199.724539
# Epoch 9540:  Error = 199.724568
# Epoch 9541:  Error = 199.724598
# Epoch 9542:  Error = 199.724628
# Epoch 9543:  Error = 199.724658
# Epoch 9544:  Error = 199.724688
# Epoch 9545:  Error = 199.724718
# Epoch 9546:  Error = 199.724747
# Epoch 9547:  Error = 199.724777
# Epoch 9548:  Error = 199.724807
# Epoch 9549:  Error = 199.724837
# Epoch 9550:  Error = 199.724867
# Epoch 9551:  Error = 199.724896
# Epoch 9552:  Error = 199.724926
# Epoch 9553:  Error = 199.724956
# Epoch 9554:  Error = 199.724986
# Epoch 9555:  Error = 199.725015
# Epoch 9556:  Error = 199.725045
# Epoch 9557:  Error = 199.725075
# Epoch 9558:  Error = 199.725105
# Epoch 9559:  Error = 199.725134
# Epoch 9560:  Error = 199.725164
# Epoch 9561:  Error = 199.725194
# Epoch 9562:  Error = 199.725223
# Epoch 9563:  Error = 199.725253
# Epoch 9564:  Error = 199.725283
# Epoch 9565:  Error = 199.725312
# Epoch 9566:  Error = 199.725342
# Epoch 9567:  Error = 199.725372
# Epoch 9568:  Error = 199.725401
# Epoch 9569:  Error = 199.725431
# Epoch 9570:  Error = 199.725461
# Epoch 9571:  Error = 199.725490
# Epoch 9572:  Error = 199.725520
# Epoch 9573:  Error = 199.725550
# Epoch 9574:  Error = 199.725579
# Epoch 9575:  Error = 199.725609
# Epoch 9576:  Error = 199.725639
# Epoch 9577:  Error = 199.725668
# Epoch 9578:  Error = 199.725698
# Epoch 9579:  Error = 199.725727
# Epoch 9580:  Error = 199.725757
# Epoch 9581:  Error = 199.725787
# Epoch 9582:  Error = 199.725816
# Epoch 9583:  Error = 199.725846
# Epoch 9584:  Error = 199.725875
# Epoch 9585:  Error = 199.725905
# Epoch 9586:  Error = 199.725934
# Epoch 9587:  Error = 199.725964
# Epoch 9588:  Error = 199.725993
# Epoch 9589:  Error = 199.726023
# Epoch 9590:  Error = 199.726052
# Epoch 9591:  Error = 199.726082
# Epoch 9592:  Error = 199.726111
# Epoch 9593:  Error = 199.726141
# Epoch 9594:  Error = 199.726170
# Epoch 9595:  Error = 199.726200
# Epoch 9596:  Error = 199.726229
# Epoch 9597:  Error = 199.726259
# Epoch 9598:  Error = 199.726288
# Epoch 9599:  Error = 199.726318
# Epoch 9600:  Error = 199.726347
# Epoch 9601:  Error = 199.726377
# Epoch 9602:  Error = 199.726406
# Epoch 9603:  Error = 199.726436
# Epoch 9604:  Error = 199.726465
# Epoch 9605:  Error = 199.726495
# Epoch 9606:  Error = 199.726524
# Epoch 9607:  Error = 199.726553
# Epoch 9608:  Error = 199.726583
# Epoch 9609:  Error = 199.726612
# Epoch 9610:  Error = 199.726642
# Epoch 9611:  Error = 199.726671
# Epoch 9612:  Error = 199.726700
# Epoch 9613:  Error = 199.726730
# Epoch 9614:  Error = 199.726759
# Epoch 9615:  Error = 199.726789
# Epoch 9616:  Error = 199.726818
# Epoch 9617:  Error = 199.726847
# Epoch 9618:  Error = 199.726877
# Epoch 9619:  Error = 199.726906
# Epoch 9620:  Error = 199.726935
# Epoch 9621:  Error = 199.726965
# Epoch 9622:  Error = 199.726994
# Epoch 9623:  Error = 199.727023
# Epoch 9624:  Error = 199.727053
# Epoch 9625:  Error = 199.727082
# Epoch 9626:  Error = 199.727111
# Epoch 9627:  Error = 199.727141
# Epoch 9628:  Error = 199.727170
# Epoch 9629:  Error = 199.727199
# Epoch 9630:  Error = 199.727228
# Epoch 9631:  Error = 199.727258
# Epoch 9632:  Error = 199.727287
# Epoch 9633:  Error = 199.727316
# Epoch 9634:  Error = 199.727345
# Epoch 9635:  Error = 199.727375
# Epoch 9636:  Error = 199.727404
# Epoch 9637:  Error = 199.727433
# Epoch 9638:  Error = 199.727462
# Epoch 9639:  Error = 199.727492
# Epoch 9640:  Error = 199.727521
# Epoch 9641:  Error = 199.727550
# Epoch 9642:  Error = 199.727579
# Epoch 9643:  Error = 199.727608
# Epoch 9644:  Error = 199.727638
# Epoch 9645:  Error = 199.727667
# Epoch 9646:  Error = 199.727696
# Epoch 9647:  Error = 199.727725
# Epoch 9648:  Error = 199.727754
# Epoch 9649:  Error = 199.727783
# Epoch 9650:  Error = 199.727813
# Epoch 9651:  Error = 199.727842
# Epoch 9652:  Error = 199.727871
# Epoch 9653:  Error = 199.727900
# Epoch 9654:  Error = 199.727929
# Epoch 9655:  Error = 199.727958
# Epoch 9656:  Error = 199.727987
# Epoch 9657:  Error = 199.728017
# Epoch 9658:  Error = 199.728046
# Epoch 9659:  Error = 199.728075
# Epoch 9660:  Error = 199.728104
# Epoch 9661:  Error = 199.728133
# Epoch 9662:  Error = 199.728162
# Epoch 9663:  Error = 199.728191
# Epoch 9664:  Error = 199.728220
# Epoch 9665:  Error = 199.728249
# Epoch 9666:  Error = 199.728278
# Epoch 9667:  Error = 199.728307
# Epoch 9668:  Error = 199.728336
# Epoch 9669:  Error = 199.728365
# Epoch 9670:  Error = 199.728394
# Epoch 9671:  Error = 199.728423
# Epoch 9672:  Error = 199.728452
# Epoch 9673:  Error = 199.728481
# Epoch 9674:  Error = 199.728510
# Epoch 9675:  Error = 199.728539
# Epoch 9676:  Error = 199.728568
# Epoch 9677:  Error = 199.728597
# Epoch 9678:  Error = 199.728626
# Epoch 9679:  Error = 199.728655
# Epoch 9680:  Error = 199.728684
# Epoch 9681:  Error = 199.728713
# Epoch 9682:  Error = 199.728742
# Epoch 9683:  Error = 199.728771
# Epoch 9684:  Error = 199.728800
# Epoch 9685:  Error = 199.728829
# Epoch 9686:  Error = 199.728858
# Epoch 9687:  Error = 199.728887
# Epoch 9688:  Error = 199.728916
# Epoch 9689:  Error = 199.728945
# Epoch 9690:  Error = 199.728974
# Epoch 9691:  Error = 199.729003
# Epoch 9692:  Error = 199.729032
# Epoch 9693:  Error = 199.729060
# Epoch 9694:  Error = 199.729089
# Epoch 9695:  Error = 199.729118
# Epoch 9696:  Error = 199.729147
# Epoch 9697:  Error = 199.729176
# Epoch 9698:  Error = 199.729205
# Epoch 9699:  Error = 199.729234
# Epoch 9700:  Error = 199.729262
# Epoch 9701:  Error = 199.729291
# Epoch 9702:  Error = 199.729320
# Epoch 9703:  Error = 199.729349
# Epoch 9704:  Error = 199.729378
# Epoch 9705:  Error = 199.729407
# Epoch 9706:  Error = 199.729435
# Epoch 9707:  Error = 199.729464
# Epoch 9708:  Error = 199.729493
# Epoch 9709:  Error = 199.729522
# Epoch 9710:  Error = 199.729551
# Epoch 9711:  Error = 199.729579
# Epoch 9712:  Error = 199.729608
# Epoch 9713:  Error = 199.729637
# Epoch 9714:  Error = 199.729666
# Epoch 9715:  Error = 199.729694
# Epoch 9716:  Error = 199.729723
# Epoch 9717:  Error = 199.729752
# Epoch 9718:  Error = 199.729781
# Epoch 9719:  Error = 199.729809
# Epoch 9720:  Error = 199.729838
# Epoch 9721:  Error = 199.729867
# Epoch 9722:  Error = 199.729896
# Epoch 9723:  Error = 199.729924
# Epoch 9724:  Error = 199.729953
# Epoch 9725:  Error = 199.729982
# Epoch 9726:  Error = 199.730010
# Epoch 9727:  Error = 199.730039
# Epoch 9728:  Error = 199.730068
# Epoch 9729:  Error = 199.730096
# Epoch 9730:  Error = 199.730125
# Epoch 9731:  Error = 199.730154
# Epoch 9732:  Error = 199.730182
# Epoch 9733:  Error = 199.730211
# Epoch 9734:  Error = 199.730240
# Epoch 9735:  Error = 199.730268
# Epoch 9736:  Error = 199.730297
# Epoch 9737:  Error = 199.730326
# Epoch 9738:  Error = 199.730354
# Epoch 9739:  Error = 199.730383
# Epoch 9740:  Error = 199.730412
# Epoch 9741:  Error = 199.730440
# Epoch 9742:  Error = 199.730469
# Epoch 9743:  Error = 199.730497
# Epoch 9744:  Error = 199.730526
# Epoch 9745:  Error = 199.730554
# Epoch 9746:  Error = 199.730583
# Epoch 9747:  Error = 199.730612
# Epoch 9748:  Error = 199.730640
# Epoch 9749:  Error = 199.730669
# Epoch 9750:  Error = 199.730697
# Epoch 9751:  Error = 199.730726
# Epoch 9752:  Error = 199.730754
# Epoch 9753:  Error = 199.730783
# Epoch 9754:  Error = 199.730811
# Epoch 9755:  Error = 199.730840
# Epoch 9756:  Error = 199.730868
# Epoch 9757:  Error = 199.730897
# Epoch 9758:  Error = 199.730925
# Epoch 9759:  Error = 199.730954
# Epoch 9760:  Error = 199.730982
# Epoch 9761:  Error = 199.731011
# Epoch 9762:  Error = 199.731039
# Epoch 9763:  Error = 199.731068
# Epoch 9764:  Error = 199.731096
# Epoch 9765:  Error = 199.731125
# Epoch 9766:  Error = 199.731153
# Epoch 9767:  Error = 199.731182
# Epoch 9768:  Error = 199.731210
# Epoch 9769:  Error = 199.731239
# Epoch 9770:  Error = 199.731267
# Epoch 9771:  Error = 199.731295
# Epoch 9772:  Error = 199.731324
# Epoch 9773:  Error = 199.731352
# Epoch 9774:  Error = 199.731381
# Epoch 9775:  Error = 199.731409
# Epoch 9776:  Error = 199.731437
# Epoch 9777:  Error = 199.731466
# Epoch 9778:  Error = 199.731494
# Epoch 9779:  Error = 199.731523
# Epoch 9780:  Error = 199.731551
# Epoch 9781:  Error = 199.731579
# Epoch 9782:  Error = 199.731608
# Epoch 9783:  Error = 199.731636
# Epoch 9784:  Error = 199.731664
# Epoch 9785:  Error = 199.731693
# Epoch 9786:  Error = 199.731721
# Epoch 9787:  Error = 199.731749
# Epoch 9788:  Error = 199.731778
# Epoch 9789:  Error = 199.731806
# Epoch 9790:  Error = 199.731834
# Epoch 9791:  Error = 199.731863
# Epoch 9792:  Error = 199.731891
# Epoch 9793:  Error = 199.731919
# Epoch 9794:  Error = 199.731948
# Epoch 9795:  Error = 199.731976
# Epoch 9796:  Error = 199.732004
# Epoch 9797:  Error = 199.732032
# Epoch 9798:  Error = 199.732061
# Epoch 9799:  Error = 199.732089
# Epoch 9800:  Error = 199.732117
# Epoch 9801:  Error = 199.732145
# Epoch 9802:  Error = 199.732174
# Epoch 9803:  Error = 199.732202
# Epoch 9804:  Error = 199.732230
# Epoch 9805:  Error = 199.732258
# Epoch 9806:  Error = 199.732287
# Epoch 9807:  Error = 199.732315
# Epoch 9808:  Error = 199.732343
# Epoch 9809:  Error = 199.732371
# Epoch 9810:  Error = 199.732399
# Epoch 9811:  Error = 199.732428
# Epoch 9812:  Error = 199.732456
# Epoch 9813:  Error = 199.732484
# Epoch 9814:  Error = 199.732512
# Epoch 9815:  Error = 199.732540
# Epoch 9816:  Error = 199.732568
# Epoch 9817:  Error = 199.732597
# Epoch 9818:  Error = 199.732625
# Epoch 9819:  Error = 199.732653
# Epoch 9820:  Error = 199.732681
# Epoch 9821:  Error = 199.732709
# Epoch 9822:  Error = 199.732737
# Epoch 9823:  Error = 199.732765
# Epoch 9824:  Error = 199.732793
# Epoch 9825:  Error = 199.732822
# Epoch 9826:  Error = 199.732850
# Epoch 9827:  Error = 199.732878
# Epoch 9828:  Error = 199.732906
# Epoch 9829:  Error = 199.732934
# Epoch 9830:  Error = 199.732962
# Epoch 9831:  Error = 199.732990
# Epoch 9832:  Error = 199.733018
# Epoch 9833:  Error = 199.733046
# Epoch 9834:  Error = 199.733074
# Epoch 9835:  Error = 199.733102
# Epoch 9836:  Error = 199.733130
# Epoch 9837:  Error = 199.733158
# Epoch 9838:  Error = 199.733186
# Epoch 9839:  Error = 199.733214
# Epoch 9840:  Error = 199.733243
# Epoch 9841:  Error = 199.733271
# Epoch 9842:  Error = 199.733299
# Epoch 9843:  Error = 199.733327
# Epoch 9844:  Error = 199.733355
# Epoch 9845:  Error = 199.733383
# Epoch 9846:  Error = 199.733411
# Epoch 9847:  Error = 199.733438
# Epoch 9848:  Error = 199.733466
# Epoch 9849:  Error = 199.733494
# Epoch 9850:  Error = 199.733522
# Epoch 9851:  Error = 199.733550
# Epoch 9852:  Error = 199.733578
# Epoch 9853:  Error = 199.733606
# Epoch 9854:  Error = 199.733634
# Epoch 9855:  Error = 199.733662
# Epoch 9856:  Error = 199.733690
# Epoch 9857:  Error = 199.733718
# Epoch 9858:  Error = 199.733746
# Epoch 9859:  Error = 199.733774
# Epoch 9860:  Error = 199.733802
# Epoch 9861:  Error = 199.733830
# Epoch 9862:  Error = 199.733857
# Epoch 9863:  Error = 199.733885
# Epoch 9864:  Error = 199.733913
# Epoch 9865:  Error = 199.733941
# Epoch 9866:  Error = 199.733969
# Epoch 9867:  Error = 199.733997
# Epoch 9868:  Error = 199.734025
# Epoch 9869:  Error = 199.734053
# Epoch 9870:  Error = 199.734080
# Epoch 9871:  Error = 199.734108
# Epoch 9872:  Error = 199.734136
# Epoch 9873:  Error = 199.734164
# Epoch 9874:  Error = 199.734192
# Epoch 9875:  Error = 199.734220
# Epoch 9876:  Error = 199.734247
# Epoch 9877:  Error = 199.734275
# Epoch 9878:  Error = 199.734303
# Epoch 9879:  Error = 199.734331
# Epoch 9880:  Error = 199.734359
# Epoch 9881:  Error = 199.734386
# Epoch 9882:  Error = 199.734414
# Epoch 9883:  Error = 199.734442
# Epoch 9884:  Error = 199.734470
# Epoch 9885:  Error = 199.734497
# Epoch 9886:  Error = 199.734525
# Epoch 9887:  Error = 199.734553
# Epoch 9888:  Error = 199.734581
# Epoch 9889:  Error = 199.734608
# Epoch 9890:  Error = 199.734636
# Epoch 9891:  Error = 199.734664
# Epoch 9892:  Error = 199.734692
# Epoch 9893:  Error = 199.734719
# Epoch 9894:  Error = 199.734747
# Epoch 9895:  Error = 199.734775
# Epoch 9896:  Error = 199.734802
# Epoch 9897:  Error = 199.734830
# Epoch 9898:  Error = 199.734858
# Epoch 9899:  Error = 199.734886
# Epoch 9900:  Error = 199.734913
# Epoch 9901:  Error = 199.734941
# Epoch 9902:  Error = 199.734969
# Epoch 9903:  Error = 199.734996
# Epoch 9904:  Error = 199.735024
# Epoch 9905:  Error = 199.735052
# Epoch 9906:  Error = 199.735079
# Epoch 9907:  Error = 199.735107
# Epoch 9908:  Error = 199.735134
# Epoch 9909:  Error = 199.735162
# Epoch 9910:  Error = 199.735190
# Epoch 9911:  Error = 199.735217
# Epoch 9912:  Error = 199.735245
# Epoch 9913:  Error = 199.735272
# Epoch 9914:  Error = 199.735300
# Epoch 9915:  Error = 199.735328
# Epoch 9916:  Error = 199.735355
# Epoch 9917:  Error = 199.735383
# Epoch 9918:  Error = 199.735410
# Epoch 9919:  Error = 199.735438
# Epoch 9920:  Error = 199.735466
# Epoch 9921:  Error = 199.735493
# Epoch 9922:  Error = 199.735521
# Epoch 9923:  Error = 199.735548
# Epoch 9924:  Error = 199.735576
# Epoch 9925:  Error = 199.735603
# Epoch 9926:  Error = 199.735631
# Epoch 9927:  Error = 199.735658
# Epoch 9928:  Error = 199.735686
# Epoch 9929:  Error = 199.735713
# Epoch 9930:  Error = 199.735741
# Epoch 9931:  Error = 199.735768
# Epoch 9932:  Error = 199.735796
# Epoch 9933:  Error = 199.735823
# Epoch 9934:  Error = 199.735851
# Epoch 9935:  Error = 199.735878
# Epoch 9936:  Error = 199.735906
# Epoch 9937:  Error = 199.735933
# Epoch 9938:  Error = 199.735961
# Epoch 9939:  Error = 199.735988
# Epoch 9940:  Error = 199.736016
# Epoch 9941:  Error = 199.736043
# Epoch 9942:  Error = 199.736071
# Epoch 9943:  Error = 199.736098
# Epoch 9944:  Error = 199.736125
# Epoch 9945:  Error = 199.736153
# Epoch 9946:  Error = 199.736180
# Epoch 9947:  Error = 199.736208
# Epoch 9948:  Error = 199.736235
# Epoch 9949:  Error = 199.736262
# Epoch 9950:  Error = 199.736290
# Epoch 9951:  Error = 199.736317
# Epoch 9952:  Error = 199.736345
# Epoch 9953:  Error = 199.736372
# Epoch 9954:  Error = 199.736399
# Epoch 9955:  Error = 199.736427
# Epoch 9956:  Error = 199.736454
# Epoch 9957:  Error = 199.736481
# Epoch 9958:  Error = 199.736509
# Epoch 9959:  Error = 199.736536
# Epoch 9960:  Error = 199.736563
# Epoch 9961:  Error = 199.736591
# Epoch 9962:  Error = 199.736618
# Epoch 9963:  Error = 199.736645
# Epoch 9964:  Error = 199.736673
# Epoch 9965:  Error = 199.736700
# Epoch 9966:  Error = 199.736727
# Epoch 9967:  Error = 199.736755
# Epoch 9968:  Error = 199.736782
# Epoch 9969:  Error = 199.736809
# Epoch 9970:  Error = 199.736837
# Epoch 9971:  Error = 199.736864
# Epoch 9972:  Error = 199.736891
# Epoch 9973:  Error = 199.736918
# Epoch 9974:  Error = 199.736946
# Epoch 9975:  Error = 199.736973
# Epoch 9976:  Error = 199.737000
# Epoch 9977:  Error = 199.737027
# Epoch 9978:  Error = 199.737055
# Epoch 9979:  Error = 199.737082
# Epoch 9980:  Error = 199.737109
# Epoch 9981:  Error = 199.737136
# Epoch 9982:  Error = 199.737163
# Epoch 9983:  Error = 199.737191
# Epoch 9984:  Error = 199.737218
# Epoch 9985:  Error = 199.737245
# Epoch 9986:  Error = 199.737272
# Epoch 9987:  Error = 199.737299
# Epoch 9988:  Error = 199.737327
# Epoch 9989:  Error = 199.737354
# Epoch 9990:  Error = 199.737381
# Epoch 9991:  Error = 199.737408
# Epoch 9992:  Error = 199.737435
# Epoch 9993:  Error = 199.737463
# Epoch 9994:  Error = 199.737490
# Epoch 9995:  Error = 199.737517
# Epoch 9996:  Error = 199.737544
# Epoch 9997:  Error = 199.737571
# Epoch 9998:  Error = 199.737598
# Epoch 9999:  Error = 199.737625

# %% [markdown]
# **Optional questions**
#
# 2. *Weight decay* constraint
#
# As nothing constrains the weights in the network, we can note that usually all weights vector given a multiplicative factor might be equivalent, which can stall the learning (and lead to exploding weights). The *weight decay* allows to regularize the learning by penalizing weights with a too wide amplitude. The idea is to add this constraint as a term to the final loss (which leads to an indirect "pressure" on the learning process. Therefore, the final loss will be defined as
#
# $$
# \begin{equation}
# \mathcal{L}_{final}=\mathcal{L_D} + \lambda \sum_{l} \sum_{i} \sum_{j} \left( W_{ij}^{l} \right)^{2}
# \end{equation}
# $$
#
# where the parameter $\lambda$ controls the relative importance of the two terms.
#
# 3. *Momentum* in learning
#
# Usually, in complex problems, the gradient can be very noisy and, therefore, the learning might oscillate widely. In order to reduce this problem, we can *smooth* the different gradient updates by retaining the values of the gradient at each iteration and then performing an update based on the latest gradient $\delta_{i}^{t}$ and the gradient at the previous iteration $\delta_{i}^{t-1}$. Therefore, a gradient update is applied as
#
# $$
# \begin{equation}
# \delta_{final}^{t} = \delta_{i}^{t} + m.\delta_{i}^{t-1}
# \end{equation}
# $$
#
# with $m$ the momentum parameter, which control the amount of gradient smoothing.

# %% [markdown]
# ## 3-layer audio classification
#
# Finally, we will attack a complete audio classification problem and try to perform neural network learning on a set of audio files. The data structure will be the same as the one used for parts 1 and 2. As discussed during the courses, even though a 2-layer neural network can provide non-linear boundaries, it can not perform "holes" inside those regions. In order to obtain an improved classification, we will now rely on a 3-layer neural network. The modification to the code of section 3.2 should be minimal, as the back-propagation will be similar for the new layer as one of the two others. We do not develop the math here as it is simply a re-application of the previous rules with an additional layer (which derivatives you should have generalized in the previous exercise).
#
# However, up until now, we only performed *binary classification* problems, but this time we need to obtain a decision rule for multiple classes. Therefore, we cannot rely on simply computing the distance between desired patterns and the obtained binary value. The idea here is to rely on the *softmax regression*, by considering classes as a vector of probabilities. The desired answers will therefore be considered as a set of *probabilities*, where the desired class is $1$ and the others are $0$ (called *one-hot* representation). Then, the cost function will rely on the softmax formulation
#
# $$
# \begin{equation}
# \mathcal{L_D}(\theta) = - \frac{1}{m} \left[ \sum_{i=1}^{m} \sum_{j=1}^{k} 1\left\{y^{(i)} = j\right\} log \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)} }}  \right]
# \end{equation}
# $$
#
# Therefore, we compute the output of the softmax by taking
#
# $$
# \begin{equation}
# p(y^{(i)} = j | x^{(i)}; \theta) = \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)}} }
# \end{equation}
# $$
#
# By taking derivatives, we can show that the gradient of the softmax layer is
#
# $$
# \begin{equation}
# \nabla_{\theta_{j}} \mathcal{L_D}(\theta) = - \frac{1}{m} \sum_{i=1}^{m}{ \left[ x^{(i)} \left( 1\{ y^{(i)} = j\}  - p(y^{(i)} = j \mid x^{(i)}, \theta) \right) \right]}
# \end{equation}
# $$

# %% [markdown]
# ### Sweet activation functions
#
# As discussed in the course, the interest of stacking layers is that there is an _activation function_, which allows non-linear interactions between the dimensions (and avoids to only compute a single huge affine transform). Although the `sigmoid` function has been historically the most used, there has been some large developments since. Notably the `ReLU` (Rectified Linear Unit) is one of the major difference in modern networks (we will see more about that in a later course)

# %%
# Function for computing the Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def dsigmoid(a):
    return a * (1.0 - a)
# Function for computing the ReLU activation
def relu(x):
    return np.maximum(0, x)
def drelu(x):
    return 1 / (1 + np.exp(-x))
# Function for computing the Tanh activation
def tanh(x):
    return np.tanh(x);
def dtanh(x): 
    return np.cosh(x) ^ -2

# %% [markdown]
# Here, we plot some simple examples of what these activation functions look like. You can try to rely on these functions in your previous training code and witness the differences in training.

# %%
from helper_plot import prep_plots, finalize_plots
funcs = [('sigmoid',sigmoid,'red'), ('tanh',tanh,'orange'), ('relu',relu,'yellow')]
axes = prep_plots([funcs[0][0], funcs[1][0], funcs[2][0]], fig_size=(18,5), fig_num=1)
x_plot = np.linspace(-5,5,100)
np.maximum(0, x_plot)
for f in range(3):
    axes[f].plot(x_plot, funcs[f][1](x_plot), color=funcs[f][2], linewidth=4, label=funcs[f][0])
finalize_plots(axes, fig_title="Activation functions")

# %% [markdown]
# ## Coding the whole network from scratch
#
# You should now have all the tools necessary to apply neural networks from scratch to a more complex problem. In the following exercise, we simply removed any guideline code, and you need to code all the procedure for training a NN and **apply it to audio data**. You will use the spectral features discussed in the previous exercise as an input.
#
# ***
#
# **Exercise**
#
#   1. Based on the previous neural network, upgrade the code to a 3-layer neural network
#   2. Implement the *softmax regression* on top of your 3-layer network
#   3. Use the provided code to perform classification on a pre-defined set of features
#   4. As previously, change the set of features to assess their different accuracies
#   5. Evaluate the neural network accuracy for all features combinations
#   6. What happens if the learning rate is too large ? What is this phenomenon ?
#   7. (Optional) Perform a more advanced visualization of the learning process.
#
# ***

# %%
# Iterate for a fixed number of iterations

from helper_data import import_dataset
from helper_data import compute_transforms
# 0.1 - Import the classification dataset
class_path = 'data/classification';
data_struct = import_dataset(class_path, 'classification');

data_struct = compute_transforms(data_struct);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ccb72b344253> in <module>
#       5 # 0.1 - Import the classification dataset
#       6 class_path = 'data/classification';
# ----> 7 data_struct = import_dataset(class_path, 'classification');
#       8
#       9 data_struct = compute_transforms(data_struct);
#
# c:\Users\33689\Documents\Travail scolaire\M2 ATIAM\Informatique\atiam_ml_fork\helper_data.py in import_dataset(classPath, typeD)
#      14         classesPaths = []
#      15         # List classes first
# ---> 16         for item in os.listdir(classPath):
#      17             if os.path.isdir(os.path.join(classPath, item)):
#      18                 classesPaths.append(item)
#
# FileNotFoundError: [WinError 3] Le chemin d’accès spécifié est introuvable: 'data/classification'

# %%
from helper_data import compute_features
data_struct = compute_features(data_struct);


#nInputs = len(inputs)

#weights1 = (np.random.randn(3, nInputs) - 0.5)


#weights2 = np.random.randn()

# %%
for epoch in range(500):
    
    
    print('Epoch %3d:  Error = %f\n' % epoch, TSS);
    if TSS < TSS_Limit:
        break
plo_boundary(np.concatenate(bias1, weights1), epoch, '-');

# %% [markdown]
# ## Using Pytorch to enjoy life
#
# Up to now, we have been writing every operations by ourselves (in order to better understand the mathematics behind NN). However, there exists of course some simplifying libraries that provide large simplifications to this question.
#
# One of the most powerful and complete library of this sort is `Pytorch`, which has been developed for several years (even prior to the recent boom of deep learning). `Pytorch` provides a large set of pre-coded layers, but also **computational graphs** and **autograd**, which are very powerful paradigms allowing to define complex operators and automatically taking derivatives.
#
# ### Defining our network
#
# When building neural networks we frequently think of arranging the computation into layers, some of which have learnable parameters which will be optimized during learning. In `PyTorch`, the `nn` package provides higher-level abstractions over raw computational graphs that are useful for building neural networks. The `nn` package defines a set of `Modules`, which are roughly equivalent to neural network layers. A `Module` receives input `Tensors` and computes output `Tensors`, but may also hold internal state such as `Tensors` containing learnable parameters. The nn package also defines a set of useful loss functions that are commonly used when training neural networks.
#
# In the following example, we use the `nn` package to show how easy it is to instantiate our previous three-layers network

# %%
import torch
# Define the input dimensions
in_size = 1000
# Number of neurons in a layer
hidden_size = 100
# Output (target) dimension
output_size = 10
# Use the nn package to define our model and loss function.
model = torch.nn.Sequential(
    torch.nn.Linear(in_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, output_size),
    torch.nn.Softmax(dim=1)
)

# %% [markdown]
# ### Optimizing the network
#
# Up to this point we have updated the weights of our models by manually performing the gradient descent algorithm (changing the parameters vectors). Although this is not a huge burden for simple optimization algorithms like stochastic gradient descent, in practice we often train neural networks using more sophisticated optimizers like AdaGrad, RMSProp or Adam (that we will see later in this course)
#
# The `optim` package in PyTorch abstracts the idea of an optimization algorithm and provides implementations of commonly used optimization algorithms, and greatly simplfies the training loop associated with training a neural network.
#
# For the sake of presentation we will use random inputs $\mathbf{x}$ that should be matched with random outputs $\mathbf{y}$

# %%
batch_size = 64
# Create random Tensors to hold inputs and outputs
x = torch.randn(N, D_in)
y = torch.randn(N, D_out)

# %% [markdown]
# In the following example we optimize the model using the Adam algorithm provided by the `optim` package, based on a `MSE` loss.

# %%
# Learning rate
learning_rate = 1e-4
# Loss function that we will use
loss_fn = torch.nn.MSELoss(reduction='sum')
# Optimizer to fit the weights of the network
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
for t in range(500):
    # Forward pass: compute predicted y by passing x to the model.
    y_pred = model(x)
    # Compute the loss.
    loss = loss_fn(y_pred, y)
    # Before the backward pass, zero all of the network gradients
    optimizer.zero_grad()
    # Backward pass: compute gradient of the loss with respect to parameters
    loss.backward()
    # Calling the step function to update the parameters
    optimizer.step()

# %% [markdown]
# ## Using Pytorch to classify audio
#
# Now that we know the main components of `Pytorch` to define and optimize networks, your assignement is to define a complete classification problem from audio data, by relying on this toolbox
#
# ***
#
# **Exercise**
#
#   1. Use `Pytorch` to define a model for audio classification
#   2. Import the audio features dataset and check that your model produces an output
#   3. Write the optimization loop (think carefully about the _loss function_
#   4. As previously, change the set of features to assess their different accuracies
#   5. Think of how you could use more complex features (time series, audio, STFT) to classify your data
#
# ***

# %%
######################
# YOUR CODE GOES HERE
######################
